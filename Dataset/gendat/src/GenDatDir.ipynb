# %% [markdown]
# ## Generate dataset for many directories

# %% [markdown]
# ## Generate .dat

# %%
import os
import inspect
from PIL import Image

# # Lots images
# lotsGoodImages = 917
# lotsBadImages = 1469

# Name of your directory
nameDir = './../data/sort_dataset/'

listOfFiles = os.listdir('./' + nameDir)
wastefiles = ['.DS_Store', '.ipynb_checkpoints']

gendat = 'sort_dataset' + '.dat'
dat = open(gendat, 'a')

for i in listOfFiles:
    if i not in wastefiles:
        # i - Directory
        print(i + '\n')
        listOfgoodFiles = os.listdir('./../data/sort_dataset/' + i) # path for goodNameDir
        
        for j in listOfgoodFiles:
            if j not in wastefiles:
                
                lotsGoodImages = len(listOfgoodFiles) - 1 # .DS_STORE
                
                print(j + '\n' + '\n' + '\n' + '\n')
                img = Image.open('./../data/sort_dataset/' + i + '/' + j)
                dat.write('sort_dataset/' + i + '/' + j + ' 1 0 0 ')
                # write coordinates of image
                dat.write(str(img.size[0]) + ' ' + str(img.size[1]) + '\n')
                
                print('sort_dataset/' + i + '/' + j + ' 1 0 0 ' + str(img.size[0]) + ' ' + str(img.size[1]))
                
#                 for im in range(1, lotsGoodImages + 1):
#                     img = Image.open('./sort_dataset/' + i + '/' + str(im) + '.jpg')
#                     dat.write('./sort_dataset/' + i + '/' + str(im) + '.jpg' + ' 1 0 0 ')
#                     # write coordinates of image
#                     dat.write(str(img.size[0]) + ' ' + str(img.size[1]) + '\n')

                
        
dat.close()


# # Directories with your PATH
# listOfgoodFiles = os.listdir('./' + goodNameDir) # path for goodNameDir
# listOfbadFiles = os.listdir('./' + badNameDir) # path for badNameDir
# wastefiles = ['.DS_Store', 'dataset.ipynb', '.ipynb_checkpoints']

# gendat = './'+ goodNameDir +'.dat'
# dat = open(gendat, 'a')
# for im in range(1, lotsGoodImages + 1):
#     img = Image.open('./' + goodNameDir + '/' + str(im) + '.jpg')
#     dat.write(goodNameDir + '/' + str(im) + '.jpg' + ' 1 0 0 ')
#     # write coordinates of image
#     dat.write(str(img.size[0]) + ' ' + str(img.size[1]) + '\n')
# dat.close()

# gendat = './' + badNameDir + '.dat'
# dat = open(gendat, 'a')    
# for im in range(1, lotsBadImages + 1):
#     img = Image.open('./' + badNameDir + '/' + str(im) + '.jpg')
#     dat.write(badNameDir + '/' + str(im) + '.jpg' + '\n')
# dat.close()
# Out:
# hand
#
# 823.JPG
#
#
#
#
# sort_dataset/hand/823.JPG 1 0 0 43 46
# 837.JPG
#
#
#
#
# sort_dataset/hand/837.JPG 1 0 0 41 41
# 638.JPG
#
#
#
#
# sort_dataset/hand/638.JPG 1 0 0 87 81
# 604.JPG
#
#
#
#
# sort_dataset/hand/604.JPG 1 0 0 42 46
# 610.JPG
#
#
#
#
# sort_dataset/hand/610.JPG 1 0 0 29 30
# 348.JPG
#
#
#
#
# sort_dataset/hand/348.JPG 1 0 0 114 91
# 360.JPG
#
#
#
#
# sort_dataset/hand/360.JPG 1 0 0 40 35
# 406.JPG
#
#
#
#
# sort_dataset/hand/406.JPG 1 0 0 59 52
# 412.JPG
#
#
#
#
# sort_dataset/hand/412.JPG 1 0 0 102 93
# 374.JPG
#
#
#
#
# sort_dataset/hand/374.JPG 1 0 0 66 67
# 599.JPG
#
#
#
#
# sort_dataset/hand/599.JPG 1 0 0 43 46
# 572.JPG
#
#
#
#
# sort_dataset/hand/572.JPG 1 0 0 66 54
# 566.JPG
#
#
#
#
# sort_dataset/hand/566.JPG 1 0 0 83 75
# 758.JPG
#
#
#
#
# sort_dataset/hand/758.JPG 1 0 0 65 55
# 770.JPG
#
#
#
#
# sort_dataset/hand/770.JPG 1 0 0 32 31
# 764.JPG
#
#
#
#
# sort_dataset/hand/764.JPG 1 0 0 55 57
# 765.JPG
#
#
#
#
# sort_dataset/hand/765.JPG 1 0 0 56 62
# 771.JPG
#
#
#
#
# sort_dataset/hand/771.JPG 1 0 0 30 38
# 759.JPG
#
#
#
#
# sort_dataset/hand/759.JPG 1 0 0 66 69
# 567.JPG
#
#
#
#
# sort_dataset/hand/567.JPG 1 0 0 35 34
# 573.JPG
#
#
#
#
# sort_dataset/hand/573.JPG 1 0 0 52 52
# 598.JPG
#
#
#
#
# sort_dataset/hand/598.JPG 1 0 0 77 83
# 413.JPG
#
#
#
#
# sort_dataset/hand/413.JPG 1 0 0 53 55
# 375.JPG
#
#
#
#
# sort_dataset/hand/375.JPG 1 0 0 142 130
# 361.JPG
#
#
#
#
# sort_dataset/hand/361.JPG 1 0 0 119 128
# 407.JPG
#
#
#
#
# sort_dataset/hand/407.JPG 1 0 0 67 63
# 349.JPG
#
#
#
#
# sort_dataset/hand/349.JPG 1 0 0 31 31
# 611.JPG
#
#
#
#
# sort_dataset/hand/611.JPG 1 0 0 66 60
# 605.JPG
#
#
#
#
# sort_dataset/hand/605.JPG 1 0 0 36 41
# 639.JPG
#
#
#
#
# sort_dataset/hand/639.JPG 1 0 0 84 66
# 836.JPG
#
#
#
#
# sort_dataset/hand/836.JPG 1 0 0 59 62
# 822.JPG
#
#
#
#
# sort_dataset/hand/822.JPG 1 0 0 130 103
# 834.JPG
#
#
#
#
# sort_dataset/hand/834.JPG 1 0 0 34 44
# 820.JPG
#
#
#
#
# sort_dataset/hand/820.JPG 1 0 0 35 39
# 808.JPG
#
#
#
#
# sort_dataset/hand/808.JPG 1 0 0 44 52
# 613.JPG
#
#
#
#
# sort_dataset/hand/613.JPG 1 0 0 104 90
# 607.JPG
#
#
#
#
# sort_dataset/hand/607.JPG 1 0 0 57 61
# 388.JPG
#
#
#
#
# sort_dataset/hand/388.JPG 1 0 0 112 102
# 439.JPG
#
#
#
#
# sort_dataset/hand/439.JPG 1 0 0 36 37
# 377.JPG
#
#
#
#
# sort_dataset/hand/377.JPG 1 0 0 42 35
# 411.JPG
#
#
#
#
# sort_dataset/hand/411.JPG 1 0 0 79 78
# 405.JPG
#
#
#
#
# sort_dataset/hand/405.JPG 1 0 0 107 82
# 363.JPG
#
#
#
#
# sort_dataset/hand/363.JPG 1 0 0 45 39
# 559.JPG
#
#
#
#
# sort_dataset/hand/559.JPG 1 0 0 41 47
# 565.JPG
#
#
#
#
# sort_dataset/hand/565.JPG 1 0 0 39 40
# 571.JPG
#
#
#
#
# sort_dataset/hand/571.JPG 1 0 0 76 69
# 798.JPG
#
#
#
#
# sort_dataset/hand/798.JPG 1 0 0 43 51
# 767.JPG
#
#
#
#
# sort_dataset/hand/767.JPG 1 0 0 48 52
# 773.JPG
#
#
#
#
# sort_dataset/hand/773.JPG 1 0 0 67 60
# 772.JPG
#
#
#
#
# sort_dataset/hand/772.JPG 1 0 0 127 119
# 766.JPG
#
#
#
#
# sort_dataset/hand/766.JPG 1 0 0 70 59
# 799.JPG
#
#
#
#
# sort_dataset/hand/799.JPG 1 0 0 38 39
# 570.JPG
#
#
#
#
# sort_dataset/hand/570.JPG 1 0 0 41 41
# 564.JPG
#
#
#
#
# sort_dataset/hand/564.JPG 1 0 0 60 61
# 558.JPG
#
#
#
#
# sort_dataset/hand/558.JPG 1 0 0 65 54
# 404.JPG
#
#
#
#
# sort_dataset/hand/404.JPG 1 0 0 29 38
# 362.JPG
#
#
#
#
# sort_dataset/hand/362.JPG 1 0 0 31 36
# 376.JPG
#
#
#
#
# sort_dataset/hand/376.JPG 1 0 0 130 127
# 410.JPG
#
#
#
#
# sort_dataset/hand/410.JPG 1 0 0 31 31
# 438.JPG
#
#
#
#
# sort_dataset/hand/438.JPG 1 0 0 75 92
# 389.JPG
#
#
#
#
# sort_dataset/hand/389.JPG 1 0 0 48 37
# 606.JPG
#
#
#
#
# sort_dataset/hand/606.JPG 1 0 0 96 110
# 612.JPG
#
#
#
#
# sort_dataset/hand/612.JPG 1 0 0 85 102
# 809.JPG
#
#
#
#
# sort_dataset/hand/809.JPG 1 0 0 31 39
# 821.JPG
#
#
#
#
# sort_dataset/hand/821.JPG 1 0 0 33 31
# 835.JPG
#
#
#
#
# sort_dataset/hand/835.JPG 1 0 0 56 57
# 819.JPG
#
#
#
#
# sort_dataset/hand/819.JPG 1 0 0 40 38
# 831.JPG
#
#
#
#
# sort_dataset/hand/831.JPG 1 0 0 28 38
# 825.JPG
#
#
#
#
# sort_dataset/hand/825.JPG 1 0 0 41 41
# 616.JPG
#
#
#
#
# sort_dataset/hand/616.JPG 1 0 0 29 34
# 602.JPG
#
#
#
#
# sort_dataset/hand/602.JPG 1 0 0 42 40
# 399.JPG
#
#
#
#
# sort_dataset/hand/399.JPG 1 0 0 33 35
# 414.JPG
#
#
#
#
# sort_dataset/hand/414.JPG 1 0 0 48 54
# 372.JPG
#
#
#
#
# sort_dataset/hand/372.JPG 1 0 0 134 120
# 366.JPG
#
#
#
#
# sort_dataset/hand/366.JPG 1 0 0 106 116
# 400.JPG
#
#
#
#
# sort_dataset/hand/400.JPG 1 0 0 123 123
# 428.JPG
#
#
#
#
# sort_dataset/hand/428.JPG 1 0 0 55 54
# 560.JPG
#
#
#
#
# sort_dataset/hand/560.JPG 1 0 0 24 28
# 574.JPG
#
#
#
#
# sort_dataset/hand/574.JPG 1 0 0 81 89
# 548.JPG
#
#
#
#
# sort_dataset/hand/548.JPG 1 0 0 139 148
# 789.JPG
#
#
#
#
# sort_dataset/hand/789.JPG 1 0 0 37 37
# 762.JPG
#
#
#
#
# sort_dataset/hand/762.JPG 1 0 0 81 92
# 776.JPG
#
#
#
#
# sort_dataset/hand/776.JPG 1 0 0 48 47
# 777.JPG
#
#
#
#
# sort_dataset/hand/777.JPG 1 0 0 39 35
# 763.JPG
#
#
#
#
# sort_dataset/hand/763.JPG 1 0 0 35 34
# 788.JPG
#
#
#
#
# sort_dataset/hand/788.JPG 1 0 0 106 79
# 549.JPG
#
#
#
#
# sort_dataset/hand/549.JPG 1 0 0 113 90
# 575.JPG
#
#
#
#
# sort_dataset/hand/575.JPG 1 0 0 42 41
# 561.JPG
#
#
#
#
# sort_dataset/hand/561.JPG 1 0 0 39 44
# 429.JPG
#
#
#
#
# sort_dataset/hand/429.JPG 1 0 0 121 102
# 367.JPG
#
#
#
#
# sort_dataset/hand/367.JPG 1 0 0 75 82
# 401.JPG
#
#
#
#
# sort_dataset/hand/401.JPG 1 0 0 48 40
# 415.JPG
#
#
#
#
# sort_dataset/hand/415.JPG 1 0 0 62 78
# 373.JPG
#
#
#
#
# sort_dataset/hand/373.JPG 1 0 0 49 52
# 398.JPG
#
#
#
#
# sort_dataset/hand/398.JPG 1 0 0 45 38
# 603.JPG
#
#
#
#
# sort_dataset/hand/603.JPG 1 0 0 37 35
# 617.JPG
#
#
#
#
# sort_dataset/hand/617.JPG 1 0 0 50 43
# 824.JPG
#
#
#
#
# sort_dataset/hand/824.JPG 1 0 0 35 41
# 830.JPG
#
#
#
#
# sort_dataset/hand/830.JPG 1 0 0 78 85
# 818.JPG
#
#
#
#
# sort_dataset/hand/818.JPG 1 0 0 38 46
# 826.JPG
#
#
#
#
# sort_dataset/hand/826.JPG 1 0 0 100 85
# 832.JPG
#
#
#
#
# sort_dataset/hand/832.JPG 1 0 0 33 35
# 601.JPG
#
#
#
#
# sort_dataset/hand/601.JPG 1 0 0 42 36
# 615.JPG
#
#
#
#
# sort_dataset/hand/615.JPG 1 0 0 35 40
# 629.JPG
#
#
#
#
# sort_dataset/hand/629.JPG 1 0 0 34 33
# 403.JPG
#
#
#
#
# sort_dataset/hand/403.JPG 1 0 0 32 43
# 365.JPG
#
#
#
#
# sort_dataset/hand/365.JPG 1 0 0 39 42
# 371.JPG
#
#
#
#
# sort_dataset/hand/371.JPG 1 0 0 48 46
# 417.JPG
#
#
#
#
# sort_dataset/hand/417.JPG 1 0 0 67 61
# 359.JPG
#
#
#
#
# sort_dataset/hand/359.JPG 1 0 0 59 49
# 588.JPG
#
#
#
#
# sort_dataset/hand/588.JPG 1 0 0 34 39
# 577.JPG
#
#
#
#
# sort_dataset/hand/577.JPG 1 0 0 62 77
# 563.JPG
#
#
#
#
# sort_dataset/hand/563.JPG 1 0 0 38 42
# 775.JPG
#
#
#
#
# sort_dataset/hand/775.JPG 1 0 0 29 36
# 761.JPG
#
#
#
#
# sort_dataset/hand/761.JPG 1 0 0 49 47
# 749.JPG
#
#
#
#
# sort_dataset/hand/749.JPG 1 0 0 44 43
# 748.JPG
#
#
#
#
# sort_dataset/hand/748.JPG 1 0 0 64 52
# 760.JPG
#
#
#
#
# sort_dataset/hand/760.JPG 1 0 0 52 55
# 774.JPG
#
#
#
#
# sort_dataset/hand/774.JPG 1 0 0 28 27
# 562.JPG
#
#
#
#
# sort_dataset/hand/562.JPG 1 0 0 39 48
# 576.JPG
#
#
#
#
# sort_dataset/hand/576.JPG 1 0 0 111 100
# 589.JPG
#
#
#
#
# sort_dataset/hand/589.JPG 1 0 0 48 53
# 358.JPG
#
#
#
#
# sort_dataset/hand/358.JPG 1 0 0 26 31
# 370.JPG
#
#
#
#
# sort_dataset/hand/370.JPG 1 0 0 49 57
# 416.JPG
#
#
#
#
# sort_dataset/hand/416.JPG 1 0 0 31 42
# 402.JPG
#
#
#
#
# sort_dataset/hand/402.JPG 1 0 0 47 47
# 364.JPG
#
#
#
#
# sort_dataset/hand/364.JPG 1 0 0 45 44
# 628.JPG
#
#
#
#
# sort_dataset/hand/628.JPG 1 0 0 30 34
# 614.JPG
#
#
#
#
# sort_dataset/hand/614.JPG 1 0 0 39 47
# 600.JPG
#
#
#
#
# sort_dataset/hand/600.JPG 1 0 0 40 43
# 833.JPG
#
#
#
#
# sort_dataset/hand/833.JPG 1 0 0 144 150
# 827.JPG
#
#
#
#
# sort_dataset/hand/827.JPG 1 0 0 42 53
# 698.JPG
#
#
#
#
# sort_dataset/hand/698.JPG 1 0 0 92 87
# 840.JPG
#
#
#
#
# sort_dataset/hand/840.JPG 1 0 0 48 37
# 854.JPG
#
#
#
#
# sort_dataset/hand/854.JPG 1 0 0 65 50
# 667.JPG
#
#
#
#
# sort_dataset/hand/667.JPG 1 0 0 40 45
# 673.JPG
#
#
#
#
# sort_dataset/hand/673.JPG 1 0 0 38 43
# 459.JPG
#
#
#
#
# sort_dataset/hand/459.JPG 1 0 0 59 64
# 465.JPG
#
#
#
#
# sort_dataset/hand/465.JPG 1 0 0 108 99
# 471.JPG
#
#
#
#
# sort_dataset/hand/471.JPG 1 0 0 86 80
# 539.JPG
#
#
#
#
# sort_dataset/hand/539.JPG 1 0 0 91 85
# 511.JPG
#
#
#
#
# sort_dataset/hand/511.JPG 1 0 0 97 94
# 505.JPG
#
#
#
#
# sort_dataset/hand/505.JPG 1 0 0 47 38
# 713.JPG
#
#
#
#
# sort_dataset/hand/713.JPG 1 0 0 26 34
# 707.JPG
#
#
#
#
# sort_dataset/hand/707.JPG 1 0 0 32 34
# 706.JPG
#
#
#
#
# sort_dataset/hand/706.JPG 1 0 0 40 37
# 712.JPG
#
#
#
#
# sort_dataset/hand/712.JPG 1 0 0 79 83
# 504.JPG
#
#
#
#
# sort_dataset/hand/504.JPG 1 0 0 155 129
# 510.JPG
#
#
#
#
# sort_dataset/hand/510.JPG 1 0 0 43 35
# 538.JPG
#
#
#
#
# sort_dataset/hand/538.JPG 1 0 0 47 44
# 470.JPG
#
#
#
#
# sort_dataset/hand/470.JPG 1 0 0 42 43
# 464.JPG
#
#
#
#
# sort_dataset/hand/464.JPG 1 0 0 28 28
# 458.JPG
#
#
#
#
# sort_dataset/hand/458.JPG 1 0 0 76 80
# 672.JPG
#
#
#
#
# sort_dataset/hand/672.JPG 1 0 0 40 40
# 666.JPG
#
#
#
#
# sort_dataset/hand/666.JPG 1 0 0 51 51
# 855.JPG
#
#
#
#
# sort_dataset/hand/855.JPG 1 0 0 37 38
# 841.JPG
#
#
#
#
# sort_dataset/hand/841.JPG 1 0 0 61 58
# 699.JPG
#
#
#
#
# sort_dataset/hand/699.JPG 1 0 0 47 55
# 843.JPG
#
#
#
#
# sort_dataset/hand/843.JPG 1 0 0 27 30
# 658.JPG
#
#
#
#
# sort_dataset/hand/658.JPG 1 0 0 73 85
# 670.JPG
#
#
#
#
# sort_dataset/hand/670.JPG 1 0 0 37 33
# 664.JPG
#
#
#
#
# sort_dataset/hand/664.JPG 1 0 0 44 42
# 499.JPG
#
#
#
#
# sort_dataset/hand/499.JPG 1 0 0 63 64
# 328.JPG
#
#
#
#
# sort_dataset/hand/328.JPG 1 0 0 50 60
# 472.JPG
#
#
#
#
# sort_dataset/hand/472.JPG 1 0 0 41 41
# 466.JPG
#
#
#
#
# sort_dataset/hand/466.JPG 1 0 0 45 39
# 506.JPG
#
#
#
#
# sort_dataset/hand/506.JPG 1 0 0 62 62
# 512.JPG
#
#
#
#
# sort_dataset/hand/512.JPG 1 0 0 54 56
# 738.JPG
#
#
#
#
# sort_dataset/hand/738.JPG 1 0 0 29 37
# 704.JPG
#
#
#
#
# sort_dataset/hand/704.JPG 1 0 0 66 56
# 710.JPG
#
#
#
#
# sort_dataset/hand/710.JPG 1 0 0 35 46
# 711.JPG
#
#
#
#
# sort_dataset/hand/711.JPG 1 0 0 53 41
# 705.JPG
#
#
#
#
# sort_dataset/hand/705.JPG 1 0 0 62 67
# 739.JPG
#
#
#
#
# sort_dataset/hand/739.JPG 1 0 0 128 144
# 513.JPG
#
#
#
#
# sort_dataset/hand/513.JPG 1 0 0 98 88
# 507.JPG
#
#
#
#
# sort_dataset/hand/507.JPG 1 0 0 39 38
# 467.JPG
#
#
#
#
# sort_dataset/hand/467.JPG 1 0 0 112 85
# 473.JPG
#
#
#
#
# sort_dataset/hand/473.JPG 1 0 0 49 44
# 329.JPG
#
#
#
#
# sort_dataset/hand/329.JPG 1 0 0 33 40
# 498.JPG
#
#
#
#
# sort_dataset/hand/498.JPG 1 0 0 110 117
# 665.JPG
#
#
#
#
# sort_dataset/hand/665.JPG 1 0 0 44 43
# 671.JPG
#
#
#
#
# sort_dataset/hand/671.JPG 1 0 0 42 32
# 659.JPG
#
#
#
#
# sort_dataset/hand/659.JPG 1 0 0 37 36
# 842.JPG
#
#
#
#
# sort_dataset/hand/842.JPG 1 0 0 30 34
# 852.JPG
#
#
#
#
# sort_dataset/hand/852.JPG 1 0 0 44 46
# 846.JPG
#
#
#
#
# sort_dataset/hand/846.JPG 1 0 0 45 40
# 675.JPG
#
#
#
#
# sort_dataset/hand/675.JPG 1 0 0 31 34
# 661.JPG
#
#
#
#
# sort_dataset/hand/661.JPG 1 0 0 36 33
# 649.JPG
#
#
#
#
# sort_dataset/hand/649.JPG 1 0 0 97 83
# 488.JPG
#
#
#
#
# sort_dataset/hand/488.JPG 1 0 0 42 43
# 477.JPG
#
#
#
#
# sort_dataset/hand/477.JPG 1 0 0 37 37
# 463.JPG
#
#
#
#
# sort_dataset/hand/463.JPG 1 0 0 50 55
# 339.JPG
#
#
#
#
# sort_dataset/hand/339.JPG 1 0 0 44 40
# 503.JPG
#
#
#
#
# sort_dataset/hand/503.JPG 1 0 0 62 74
# 517.JPG
#
#
#
#
# sort_dataset/hand/517.JPG 1 0 0 26 28
# 701.JPG
#
#
#
#
# sort_dataset/hand/701.JPG 1 0 0 39 44
# 715.JPG
#
#
#
#
# sort_dataset/hand/715.JPG 1 0 0 41 39
# 729.JPG
#
#
#
#
# sort_dataset/hand/729.JPG 1 0 0 34 33
# 728.JPG
#
#
#
#
# sort_dataset/hand/728.JPG 1 0 0 42 49
# 714.JPG
#
#
#
#
# sort_dataset/hand/714.JPG 1 0 0 45 46
# 700.JPG
#
#
#
#
# sort_dataset/hand/700.JPG 1 0 0 55 84
# 516.JPG
#
#
#
#
# sort_dataset/hand/516.JPG 1 0 0 43 45
# 502.JPG
#
#
#
#
# sort_dataset/hand/502.JPG 1 0 0 35 40
# 338.JPG
#
#
#
#
# sort_dataset/hand/338.JPG 1 0 0 54 53
# 462.JPG
#
#
#
#
# sort_dataset/hand/462.JPG 1 0 0 36 32
# 476.JPG
#
#
#
#
# sort_dataset/hand/476.JPG 1 0 0 56 48
# 489.JPG
#
#
#
#
# sort_dataset/hand/489.JPG 1 0 0 96 67
# 648.JPG
#
#
#
#
# sort_dataset/hand/648.JPG 1 0 0 37 43
# 660.JPG
#
#
#
#
# sort_dataset/hand/660.JPG 1 0 0 41 42
# 674.JPG
#
#
#
#
# sort_dataset/hand/674.JPG 1 0 0 55 56
# 847.JPG
#
#
#
#
# sort_dataset/hand/847.JPG 1 0 0 68 68
# 853.JPG
#
#
#
#
# sort_dataset/hand/853.JPG 1 0 0 63 53
# 845.JPG
#
#
#
#
# sort_dataset/hand/845.JPG 1 0 0 53 47
# 689.JPG
#
#
#
#
# sort_dataset/hand/689.JPG 1 0 0 72 71
# 851.JPG
#
#
#
#
# sort_dataset/hand/851.JPG 1 0 0 50 42
# 662.JPG
#
#
#
#
# sort_dataset/hand/662.JPG 1 0 0 46 48
# 676.JPG
#
#
#
#
# sort_dataset/hand/676.JPG 1 0 0 35 34
# 460.JPG
#
#
#
#
# sort_dataset/hand/460.JPG 1 0 0 45 51
# 474.JPG
#
#
#
#
# sort_dataset/hand/474.JPG 1 0 0 55 56
# 448.JPG
#
#
#
#
# sort_dataset/hand/448.JPG 1 0 0 111 68
# 514.JPG
#
#
#
#
# sort_dataset/hand/514.JPG 1 0 0 31 32
# 500.JPG
#
#
#
#
# sort_dataset/hand/500.JPG 1 0 0 26 32
# 528.JPG
#
#
#
#
# sort_dataset/hand/528.JPG 1 0 0 29 34
# 716.JPG
#
#
#
#
# sort_dataset/hand/716.JPG 1 0 0 83 100
# 702.JPG
#
#
#
#
# sort_dataset/hand/702.JPG 1 0 0 42 32
# 703.JPG
#
#
#
#
# sort_dataset/hand/703.JPG 1 0 0 47 50
# 717.JPG
#
#
#
#
# sort_dataset/hand/717.JPG 1 0 0 41 39
# 529.JPG
#
#
#
#
# sort_dataset/hand/529.JPG 1 0 0 35 48
# 501.JPG
#
#
#
#
# sort_dataset/hand/501.JPG 1 0 0 46 55
# 515.JPG
#
#
#
#
# sort_dataset/hand/515.JPG 1 0 0 53 56
# 449.JPG
#
#
#
#
# sort_dataset/hand/449.JPG 1 0 0 48 43
# 475.JPG
#
#
#
#
# sort_dataset/hand/475.JPG 1 0 0 45 53
# 461.JPG
#
#
#
#
# sort_dataset/hand/461.JPG 1 0 0 38 45
# 677.JPG
#
#
#
#
# sort_dataset/hand/677.JPG 1 0 0 46 58
# 663.JPG
#
#
#
#
# sort_dataset/hand/663.JPG 1 0 0 70 69
# 850.JPG
#
#
#
#
# sort_dataset/hand/850.JPG 1 0 0 53 65
# 688.JPG
#
#
#
#
# sort_dataset/hand/688.JPG 1 0 0 86 79
# 844.JPG
#
#
#
#
# sort_dataset/hand/844.JPG 1 0 0 50 54
# 685.JPG
#
#
#
#
# sort_dataset/hand/685.JPG 1 0 0 47 44
# 691.JPG
#
#
#
#
# sort_dataset/hand/691.JPG 1 0 0 57 60
# 849.JPG
#
#
#
#
# sort_dataset/hand/849.JPG 1 0 0 32 27
# 646.JPG
#
#
#
#
# sort_dataset/hand/646.JPG 1 0 0 61 69
# 652.JPG
#
#
#
#
# sort_dataset/hand/652.JPG 1 0 0 47 49
# 487.JPG
#
#
#
#
# sort_dataset/hand/487.JPG 1 0 0 32 33
# 493.JPG
#
#
#
#
# sort_dataset/hand/493.JPG 1 0 0 58 79
# 478.JPG
#
#
#
#
# sort_dataset/hand/478.JPG 1 0 0 111 136
# 444.JPG
#
#
#
#
# sort_dataset/hand/444.JPG 1 0 0 44 42
# 322.JPG
#
#
#
#
# sort_dataset/hand/322.JPG 1 0 0 64 88
# 336.JPG
#
#
#
#
# sort_dataset/hand/336.JPG 1 0 0 66 65
# 450.JPG
#
#
#
#
# sort_dataset/hand/450.JPG 1 0 0 62 70
# 518.JPG
#
#
#
#
# sort_dataset/hand/518.JPG 1 0 0 37 45
# 530.JPG
#
#
#
#
# sort_dataset/hand/530.JPG 1 0 0 35 32
# 524.JPG
#
#
#
#
# sort_dataset/hand/524.JPG 1 0 0 52 57
# 732.JPG
#
#
#
#
# sort_dataset/hand/732.JPG 1 0 0 39 41
# 726.JPG
#
#
#
#
# sort_dataset/hand/726.JPG 1 0 0 53 44
# 727.JPG
#
#
#
#
# sort_dataset/hand/727.JPG 1 0 0 73 80
# 733.JPG
#
#
#
#
# sort_dataset/hand/733.JPG 1 0 0 34 33
# 525.JPG
#
#
#
#
# sort_dataset/hand/525.JPG 1 0 0 109 99
# 531.JPG
#
#
#
#
# sort_dataset/hand/531.JPG 1 0 0 52 51
# 519.JPG
#
#
#
#
# sort_dataset/hand/519.JPG 1 0 0 37 36
# 337.JPG
#
#
#
#
# sort_dataset/hand/337.JPG 1 0 0 33 42
# 451.JPG
#
#
#
#
# sort_dataset/hand/451.JPG 1 0 0 33 33
# 445.JPG
#
#
#
#
# sort_dataset/hand/445.JPG 1 0 0 46 45
# 323.JPG
#
#
#
#
# sort_dataset/hand/323.JPG 1 0 0 103 122
# 479.JPG
#
#
#
#
# sort_dataset/hand/479.JPG 1 0 0 31 38
# 492.JPG
#
#
#
#
# sort_dataset/hand/492.JPG 1 0 0 49 43
# 486.JPG
#
#
#
#
# sort_dataset/hand/486.JPG 1 0 0 83 95
# 653.JPG
#
#
#
#
# sort_dataset/hand/653.JPG 1 0 0 49 40
# 647.JPG
#
#
#
#
# sort_dataset/hand/647.JPG 1 0 0 64 60
# 848.JPG
#
#
#
#
# sort_dataset/hand/848.JPG 1 0 0 42 40
# 690.JPG
#
#
#
#
# sort_dataset/hand/690.JPG 1 0 0 60 63
# 684.JPG
#
#
#
#
# sort_dataset/hand/684.JPG 1 0 0 54 49
# 692.JPG
#
#
#
#
# sort_dataset/hand/692.JPG 1 0 0 61 48
# 686.JPG
#
#
#
#
# sort_dataset/hand/686.JPG 1 0 0 47 56
# 679.JPG
#
#
#
#
# sort_dataset/hand/679.JPG 1 0 0 62 59
# 651.JPG
#
#
#
#
# sort_dataset/hand/651.JPG 1 0 0 39 34
# 645.JPG
#
#
#
#
# sort_dataset/hand/645.JPG 1 0 0 26 28
# 490.JPG
#
#
#
#
# sort_dataset/hand/490.JPG 1 0 0 50 64
# 484.JPG
#
#
#
#
# sort_dataset/hand/484.JPG 1 0 0 52 37
# 453.JPG
#
#
#
#
# sort_dataset/hand/453.JPG 1 0 0 84 82
# 335.JPG
#
#
#
#
# sort_dataset/hand/335.JPG 1 0 0 98 94
# 321.JPG
#
#
#
#
# sort_dataset/hand/321.JPG 1 0 0 44 46
# 447.JPG
#
#
#
#
# sort_dataset/hand/447.JPG 1 0 0 45 42
# 527.JPG
#
#
#
#
# sort_dataset/hand/527.JPG 1 0 0 46 46
# 533.JPG
#
#
#
#
# sort_dataset/hand/533.JPG 1 0 0 90 76
# 719.JPG
#
#
#
#
# sort_dataset/hand/719.JPG 1 0 0 41 48
# 725.JPG
#
#
#
#
# sort_dataset/hand/725.JPG 1 0 0 44 52
# 731.JPG
#
#
#
#
# sort_dataset/hand/731.JPG 1 0 0 28 29
# 730.JPG
#
#
#
#
# sort_dataset/hand/730.JPG 1 0 0 41 59
# 724.JPG
#
#
#
#
# sort_dataset/hand/724.JPG 1 0 0 100 88
# 718.JPG
#
#
#
#
# sort_dataset/hand/718.JPG 1 0 0 96 118
# 532.JPG
#
#
#
#
# sort_dataset/hand/532.JPG 1 0 0 79 86
# 526.JPG
#
#
#
#
# sort_dataset/hand/526.JPG 1 0 0 70 71
# 320.JPG
#
#
#
#
# sort_dataset/hand/320.JPG 1 0 0 75 80
# 446.JPG
#
#
#
#
# sort_dataset/hand/446.JPG 1 0 0 44 42
# 452.JPG
#
#
#
#
# sort_dataset/hand/452.JPG 1 0 0 52 53
# 334.JPG
#
#
#
#
# sort_dataset/hand/334.JPG 1 0 0 32 26
# 485.JPG
#
#
#
#
# sort_dataset/hand/485.JPG 1 0 0 47 44
# 491.JPG
#
#
#
#
# sort_dataset/hand/491.JPG 1 0 0 33 37
# 644.JPG
#
#
#
#
# sort_dataset/hand/644.JPG 1 0 0 52 41
# 650.JPG
#
#
#
#
# sort_dataset/hand/650.JPG 1 0 0 57 47
# 678.JPG
#
#
#
#
# sort_dataset/hand/678.JPG 1 0 0 34 36
# 687.JPG
#
#
#
#
# sort_dataset/hand/687.JPG 1 0 0 54 54
# 693.JPG
#
#
#
#
# sort_dataset/hand/693.JPG 1 0 0 38 42
# 697.JPG
#
#
#
#
# sort_dataset/hand/697.JPG 1 0 0 30 29
# 683.JPG
#
#
#
#
# sort_dataset/hand/683.JPG 1 0 0 61 64
# 654.JPG
#
#
#
#
# sort_dataset/hand/654.JPG 1 0 0 49 50
# 640.JPG
#
#
#
#
# sort_dataset/hand/640.JPG 1 0 0 33 33
# 668.JPG
#
#
#
#
# sort_dataset/hand/668.JPG 1 0 0 39 35
# 495.JPG
#
#
#
#
# sort_dataset/hand/495.JPG 1 0 0 59 52
# 481.JPG
#
#
#
#
# sort_dataset/hand/481.JPG 1 0 0 40 39
# 330.JPG
#
#
#
#
# sort_dataset/hand/330.JPG 1 0 0 74 60
# 456.JPG
#
#
#
#
# sort_dataset/hand/456.JPG 1 0 0 46 45
# 442.JPG
#
#
#
#
# sort_dataset/hand/442.JPG 1 0 0 52 51
# 324.JPG
#
#
#
#
# sort_dataset/hand/324.JPG 1 0 0 29 35
# 522.JPG
#
#
#
#
# sort_dataset/hand/522.JPG 1 0 0 38 46
# 536.JPG
#
#
#
#
# sort_dataset/hand/536.JPG 1 0 0 32 36
# 720.JPG
#
#
#
#
# sort_dataset/hand/720.JPG 1 0 0 40 35
# 734.JPG
#
#
#
#
# sort_dataset/hand/734.JPG 1 0 0 82 75
# 708.JPG
#
#
#
#
# sort_dataset/hand/708.JPG 1 0 0 36 31
# 709.JPG
#
#
#
#
# sort_dataset/hand/709.JPG 1 0 0 39 46
# 735.JPG
#
#
#
#
# sort_dataset/hand/735.JPG 1 0 0 40 49
# 721.JPG
#
#
#
#
# sort_dataset/hand/721.JPG 1 0 0 56 57
# 537.JPG
#
#
#
#
# sort_dataset/hand/537.JPG 1 0 0 43 37
# 523.JPG
#
#
#
#
# sort_dataset/hand/523.JPG 1 0 0 99 87
# 443.JPG
#
#
#
#
# sort_dataset/hand/443.JPG 1 0 0 45 35
# 325.JPG
#
#
#
#
# sort_dataset/hand/325.JPG 1 0 0 34 40
# 331.JPG
#
#
#
#
# sort_dataset/hand/331.JPG 1 0 0 32 33
# 457.JPG
#
#
#
#
# sort_dataset/hand/457.JPG 1 0 0 71 53
# 480.JPG
#
#
#
#
# sort_dataset/hand/480.JPG 1 0 0 50 57
# 494.JPG
#
#
#
#
# sort_dataset/hand/494.JPG 1 0 0 33 36
# 669.JPG
#
#
#
#
# sort_dataset/hand/669.JPG 1 0 0 79 60
# 641.JPG
#
#
#
#
# sort_dataset/hand/641.JPG 1 0 0 42 49
# 655.JPG
#
#
#
#
# sort_dataset/hand/655.JPG 1 0 0 38 39
# 682.JPG
#
#
#
#
# sort_dataset/hand/682.JPG 1 0 0 93 111
# 696.JPG
#
#
#
#
# sort_dataset/hand/696.JPG 1 0 0 47 47
# 680.JPG
#
#
#
#
# sort_dataset/hand/680.JPG 1 0 0 43 49
# 694.JPG
#
#
#
#
# sort_dataset/hand/694.JPG 1 0 0 35 46
# 643.JPG
#
#
#
#
# sort_dataset/hand/643.JPG 1 0 0 29 32
# 657.JPG
#
#
#
#
# sort_dataset/hand/657.JPG 1 0 0 58 57
# 482.JPG
#
#
#
#
# sort_dataset/hand/482.JPG 1 0 0 98 78
# 496.JPG
#
#
#
#
# sort_dataset/hand/496.JPG 1 0 0 77 74
# 327.JPG
#
#
#
#
# sort_dataset/hand/327.JPG 1 0 0 36 37
# 441.JPG
#
#
#
#
# sort_dataset/hand/441.JPG 1 0 0 105 91
# 455.JPG
#
#
#
#
# sort_dataset/hand/455.JPG 1 0 0 97 83
# 333.JPG
#
#
#
#
# sort_dataset/hand/333.JPG 1 0 0 59 58
# 469.JPG
#
#
#
#
# sort_dataset/hand/469.JPG 1 0 0 26 31
# 535.JPG
#
#
#
#
# sort_dataset/hand/535.JPG 1 0 0 49 67
# 521.JPG
#
#
#
#
# sort_dataset/hand/521.JPG 1 0 0 35 33
# 509.JPG
#
#
#
#
# sort_dataset/hand/509.JPG 1 0 0 57 48
# 737.JPG
#
#
#
#
# sort_dataset/hand/737.JPG 1 0 0 50 40
# 723.JPG
#
#
#
#
# sort_dataset/hand/723.JPG 1 0 0 34 35
# 722.JPG
#
#
#
#
# sort_dataset/hand/722.JPG 1 0 0 54 47
# 736.JPG
#
#
#
#
# sort_dataset/hand/736.JPG 1 0 0 82 86
# 508.JPG
#
#
#
#
# sort_dataset/hand/508.JPG 1 0 0 60 49
# 520.JPG
#
#
#
#
# sort_dataset/hand/520.JPG 1 0 0 48 53
# 534.JPG
#
#
#
#
# sort_dataset/hand/534.JPG 1 0 0 31 40
# 468.JPG
#
#
#
#
# sort_dataset/hand/468.JPG 1 0 0 29 33
# 454.JPG
#
#
#
#
# sort_dataset/hand/454.JPG 1 0 0 84 79
# 332.JPG
#
#
#
#
# sort_dataset/hand/332.JPG 1 0 0 50 50
# 326.JPG
#
#
#
#
# sort_dataset/hand/326.JPG 1 0 0 30 38
# 440.JPG
# sort_dataset/hand/440.JPG 1 0 0 40 40
# 497.JPG
#
#
#
#
# sort_dataset/hand/497.JPG 1 0 0 73 67
# 483.JPG
#
#
#
#
# sort_dataset/hand/483.JPG 1 0 0 42 40
# 656.JPG
#
#
#
#
# sort_dataset/hand/656.JPG 1 0 0 35 33
# 642.JPG
#
#
#
#
# sort_dataset/hand/642.JPG 1 0 0 40 48
# 695.JPG
#
#
#
#
# sort_dataset/hand/695.JPG 1 0 0 58 47
# 681.JPG
#
#
#
#
# sort_dataset/hand/681.JPG 1 0 0 32 37
# 802.JPG
#
#
#
#
# sort_dataset/hand/802.JPG 1 0 0 26 33
# 816.JPG
#
#
#
#
# sort_dataset/hand/816.JPG 1 0 0 38 36
# 619.JPG
#
#
#
#
# sort_dataset/hand/619.JPG 1 0 0 46 47
# 625.JPG
#
#
#
#
# sort_dataset/hand/625.JPG 1 0 0 68 62
# 631.JPG
#
#
#
#
# sort_dataset/hand/631.JPG 1 0 0 72 60
# 382.JPG
#
#
#
#
# sort_dataset/hand/382.JPG 1 0 0 47 46
# 396.JPG
#
#
#
#
# sort_dataset/hand/396.JPG 1 0 0 29 36
# 369.JPG
#
#
#
#
# sort_dataset/hand/369.JPG 1 0 0 44 41
# 341.JPG
#
#
#
#
# sort_dataset/hand/341.JPG 1 0 0 101 93
# 427.JPG
#
#
#
#
# sort_dataset/hand/427.JPG 1 0 0 95 71
# 433.JPG
#
#
#
#
# sort_dataset/hand/433.JPG 1 0 0 94 78
# 355.JPG
#
#
#
#
# sort_dataset/hand/355.JPG 1 0 0 109 98
# 590.JPG
#
#
#
#
# sort_dataset/hand/590.JPG 1 0 0 30 36
# 584.JPG
#
#
#
#
# sort_dataset/hand/584.JPG 1 0 0 49 60
# 553.JPG
#
#
#
#
# sort_dataset/hand/553.JPG 1 0 0 61 57
# 547.JPG
#
#
#
#
# sort_dataset/hand/547.JPG 1 0 0 86 100
# 792.JPG
#
#
#
#
# sort_dataset/hand/792.JPG 1 0 0 44 35
# 786.JPG
#
#
#
#
# sort_dataset/hand/786.JPG 1 0 0 53 47
# 779.JPG
#
#
#
#
# sort_dataset/hand/779.JPG 1 0 0 102 106
# 751.JPG
#
#
#
#
# sort_dataset/hand/751.JPG 1 0 0 33 33
# 745.JPG
#
#
#
#
# sort_dataset/hand/745.JPG 1 0 0 26 26
# 744.JPG
#
#
#
#
# sort_dataset/hand/744.JPG 1 0 0 53 47
# 750.JPG
#
#
#
#
# sort_dataset/hand/750.JPG 1 0 0 49 43
# 778.JPG
#
#
#
#
# sort_dataset/hand/778.JPG 1 0 0 144 107
# 787.JPG
#
#
#
#
# sort_dataset/hand/787.JPG 1 0 0 43 45
# 793.JPG
#
#
#
#
# sort_dataset/hand/793.JPG 1 0 0 48 53
# 546.JPG
#
#
#
#
# sort_dataset/hand/546.JPG 1 0 0 44 39
# 552.JPG
#
#
#
#
# sort_dataset/hand/552.JPG 1 0 0 59 58
# 585.JPG
#
#
#
#
# sort_dataset/hand/585.JPG 1 0 0 30 34
# 591.JPG
#
#
#
#
# sort_dataset/hand/591.JPG 1 0 0 48 48
# 432.JPG
#
#
#
#
# sort_dataset/hand/432.JPG 1 0 0 75 58
# 354.JPG
#
#
#
#
# sort_dataset/hand/354.JPG 1 0 0 74 72
# 340.JPG
#
#
#
#
# sort_dataset/hand/340.JPG 1 0 0 33 39
# 426.JPG
#
#
#
#
# sort_dataset/hand/426.JPG 1 0 0 110 114
# 368.JPG
#
#
#
#
# sort_dataset/hand/368.JPG 1 0 0 42 44
# 397.JPG
#
#
#
#
# sort_dataset/hand/397.JPG 1 0 0 41 48
# 383.JPG
#
#
#
#
# sort_dataset/hand/383.JPG 1 0 0 32 32
# 630.JPG
#
#
#
#
# sort_dataset/hand/630.JPG 1 0 0 33 31
# 624.JPG
#
#
#
#
# sort_dataset/hand/624.JPG 1 0 0 62 56
# 618.JPG
#
#
#
#
# sort_dataset/hand/618.JPG 1 0 0 35 37
# 817.JPG
#
#
#
#
# sort_dataset/hand/817.JPG 1 0 0 69 66
# 803.JPG
#
#
#
#
# sort_dataset/hand/803.JPG 1 0 0 34 31
# 815.JPG
#
#
#
#
# sort_dataset/hand/815.JPG 1 0 0 64 59
# 801.JPG
#
#
#
#
# sort_dataset/hand/801.JPG 1 0 0 52 50
# 829.JPG
#
#
#
#
# sort_dataset/hand/829.JPG 1 0 0 31 30
# 632.JPG
#
#
#
#
# sort_dataset/hand/632.JPG 1 0 0 73 82
# 626.JPG
#
#
#
#
# sort_dataset/hand/626.JPG 1 0 0 54 53
# 395.JPG
#
#
#
#
# sort_dataset/hand/395.JPG 1 0 0 77 62
# 381.JPG
#
#
#
#
# sort_dataset/hand/381.JPG 1 0 0 50 45
# 418.JPG
#
#
#
#
# sort_dataset/hand/418.JPG 1 0 0 40 45
# 356.JPG
#
#
#
#
# sort_dataset/hand/356.JPG 1 0 0 73 84
# 430.JPG
#
#
#
#
# sort_dataset/hand/430.JPG 1 0 0 41 45
# 424.JPG
#
#
#
#
# sort_dataset/hand/424.JPG 1 0 0 37 32
# 342.JPG
#
#
#
#
# sort_dataset/hand/342.JPG 1 0 0 65 58
# 587.JPG
#
#
#
#
# sort_dataset/hand/587.JPG 1 0 0 41 48
# 593.JPG
#
#
#
#
# sort_dataset/hand/593.JPG 1 0 0 49 45
# 578.JPG
#
#
#
#
# sort_dataset/hand/578.JPG 1 0 0 23 32
# 544.JPG
#
#
#
#
# sort_dataset/hand/544.JPG 1 0 0 46 48
# 550.JPG
#
#
#
#
# sort_dataset/hand/550.JPG 1 0 0 79 66
# 785.JPG
#
#
#
#
# sort_dataset/hand/785.JPG 1 0 0 30 40
# 791.JPG
#
#
#
#
# sort_dataset/hand/791.JPG 1 0 0 83 92
# 746.JPG
#
#
#
#
# sort_dataset/hand/746.JPG 1 0 0 37 35
# 752.JPG
#
#
#
#
# sort_dataset/hand/752.JPG 1 0 0 53 64
# 753.JPG
#
#
#
#
# sort_dataset/hand/753.JPG 1 0 0 113 104
# 747.JPG
#
#
#
#
# sort_dataset/hand/747.JPG 1 0 0 56 50
# 790.JPG
#
#
#
#
# sort_dataset/hand/790.JPG 1 0 0 47 43
# 784.JPG
#
#
#
#
# sort_dataset/hand/784.JPG 1 0 0 40 48
# 551.JPG
#
#
#
#
# sort_dataset/hand/551.JPG 1 0 0 46 50
# 545.JPG
#
#
#
#
# sort_dataset/hand/545.JPG 1 0 0 46 52
# 579.JPG
#
#
#
#
# sort_dataset/hand/579.JPG 1 0 0 66 71
# 592.JPG
#
#
#
#
# sort_dataset/hand/592.JPG 1 0 0 41 34
# 586.JPG
#
#
#
#
# sort_dataset/hand/586.JPG 1 0 0 58 67
# 425.JPG
#
#
#
#
# sort_dataset/hand/425.JPG 1 0 0 51 51
# 343.JPG
#
#
#
#
# sort_dataset/hand/343.JPG 1 0 0 33 42
# 357.JPG
#
#
#
#
# sort_dataset/hand/357.JPG 1 0 0 40 41
# 431.JPG
#
#
#
#
# sort_dataset/hand/431.JPG 1 0 0 33 33
# 419.JPG
#
#
#
#
# sort_dataset/hand/419.JPG 1 0 0 49 38
# 380.JPG
#
#
#
#
# sort_dataset/hand/380.JPG 1 0 0 78 68
# 394.JPG
#
#
#
#
# sort_dataset/hand/394.JPG 1 0 0 41 43
# 627.JPG
#
#
#
#
# sort_dataset/hand/627.JPG 1 0 0 33 33
# 633.JPG
#
#
#
#
# sort_dataset/hand/633.JPG 1 0 0 55 68
# 828.JPG
#
#
#
#
# sort_dataset/hand/828.JPG 1 0 0 69 93
# 800.JPG
#
#
#
#
# sort_dataset/hand/800.JPG 1 0 0 38 43
# 814.JPG
#
#
#
#
# sort_dataset/hand/814.JPG 1 0 0 64 74
# 838.JPG
#
#
#
#
# sort_dataset/hand/838.JPG 1 0 0 29 31
# 810.JPG
#
#
#
#
# sort_dataset/hand/810.JPG 1 0 0 97 91
# 804.JPG
#
#
#
#
# sort_dataset/hand/804.JPG 1 0 0 111 121
# 637.JPG
#
#
#
#
# sort_dataset/hand/637.JPG 1 0 0 32 32
# 623.JPG
#
#
#
#
# sort_dataset/hand/623.JPG 1 0 0 67 54
# 390.JPG
#
#
#
#
# sort_dataset/hand/390.JPG 1 0 0 92 94
# 384.JPG
#
#
#
#
# sort_dataset/hand/384.JPG 1 0 0 59 61
# 435.JPG
#
#
#
#
# sort_dataset/hand/435.JPG 1 0 0 113 130
# 353.JPG
#
#
#
#
# sort_dataset/hand/353.JPG 1 0 0 104 88
# 347.JPG
#
#
#
#
# sort_dataset/hand/347.JPG 1 0 0 53 77
# 421.JPG
#
#
#
#
# sort_dataset/hand/421.JPG 1 0 0 45 47
# 409.JPG
#
#
#
#
# sort_dataset/hand/409.JPG 1 0 0 32 34
# 582.JPG
#
#
#
#
# sort_dataset/hand/582.JPG 1 0 0 34 33
# 596.JPG
#
#
#
#
# sort_dataset/hand/596.JPG 1 0 0 28 30
# 541.JPG
#
#
#
#
# sort_dataset/hand/541.JPG 1 0 0 51 49
# 555.JPG
#
#
#
#
# sort_dataset/hand/555.JPG 1 0 0 32 35
# 569.JPG
#
#
#
#
# sort_dataset/hand/569.JPG 1 0 0 24 29
# 780.JPG
#
#
#
#
# sort_dataset/hand/780.JPG 1 0 0 29 32
# 794.JPG
#
#
#
#
# sort_dataset/hand/794.JPG 1 0 0 50 48
# 743.JPG
#
#
#
#
# sort_dataset/hand/743.JPG 1 0 0 54 52
# 757.JPG
#
#
#
#
# sort_dataset/hand/757.JPG 1 0 0 40 41
# 756.JPG
#
#
#
#
# sort_dataset/hand/756.JPG 1 0 0 47 51
# 742.JPG
#
#
#
#
# sort_dataset/hand/742.JPG 1 0 0 148 120
# 795.JPG
#
#
#
#
# sort_dataset/hand/795.JPG 1 0 0 50 55
# 781.JPG
#
#
#
#
# sort_dataset/hand/781.JPG 1 0 0 37 42
# 568.JPG
#
#
#
#
# sort_dataset/hand/568.JPG 1 0 0 46 47
# 554.JPG
#
#
#
#
# sort_dataset/hand/554.JPG 1 0 0 87 75
# 540.JPG
#
#
#
#
# sort_dataset/hand/540.JPG 1 0 0 31 37
# 597.JPG
#
#
#
#
# sort_dataset/hand/597.JPG 1 0 0 53 49
# 583.JPG
#
#
#
#
# sort_dataset/hand/583.JPG 1 0 0 49 40
# 408.JPG
#
#
#
#
# sort_dataset/hand/408.JPG 1 0 0 49 44
# 346.JPG
#
#
#
#
# sort_dataset/hand/346.JPG 1 0 0 78 80
# 420.JPG
#
#
#
#
# sort_dataset/hand/420.JPG 1 0 0 49 48
# 434.JPG
#
#
#
#
# sort_dataset/hand/434.JPG 1 0 0 63 60
# 352.JPG
#
#
#
#
# sort_dataset/hand/352.JPG 1 0 0 34 35
# 385.JPG
#
#
#
#
# sort_dataset/hand/385.JPG 1 0 0 44 35
# 391.JPG
#
#
#
#
# sort_dataset/hand/391.JPG 1 0 0 79 69
# 622.JPG
#
#
#
#
# sort_dataset/hand/622.JPG 1 0 0 55 62
# 636.JPG
#
#
#
#
# sort_dataset/hand/636.JPG 1 0 0 40 35
# 805.JPG
#
#
#
#
# sort_dataset/hand/805.JPG 1 0 0 39 45
# 811.JPG
#
#
#
#
# sort_dataset/hand/811.JPG 1 0 0 94 105
# 839.JPG
#
#
#
#
# sort_dataset/hand/839.JPG 1 0 0 47 40
# 807.JPG
#
#
#
#
# sort_dataset/hand/807.JPG 1 0 0 52 53
# 813.JPG
#
#
#
#
# sort_dataset/hand/813.JPG 1 0 0 81 74
# 620.JPG
#
#
#
#
# sort_dataset/hand/620.JPG 1 0 0 42 39
# 634.JPG
#
#
#
#
# sort_dataset/hand/634.JPG 1 0 0 29 39
# 608.JPG
#
#
#
#
# sort_dataset/hand/608.JPG 1 0 0 46 50
# 387.JPG
#
#
#
#
# sort_dataset/hand/387.JPG 1 0 0 25 29
# 393.JPG
#
#
#
#
# sort_dataset/hand/393.JPG 1 0 0 46 39
# 422.JPG
#
#
#
#
# sort_dataset/hand/422.JPG 1 0 0 43 46
# 344.JPG
#
#
#
#
# sort_dataset/hand/344.JPG 1 0 0 24 29
# 350.JPG
#
#
#
#
# sort_dataset/hand/350.JPG 1 0 0 110 123
# 436.JPG
#
#
#
#
# sort_dataset/hand/436.JPG 1 0 0 25 25
# 378.JPG
#
#
#
#
# sort_dataset/hand/378.JPG 1 0 0 44 43
# 595.JPG
#
#
#
#
# sort_dataset/hand/595.JPG 1 0 0 109 108
# 581.JPG
#
#
#
#
# sort_dataset/hand/581.JPG 1 0 0 91 81
# 556.JPG
#
#
#
#
# sort_dataset/hand/556.JPG 1 0 0 57 67
# 542.JPG
#
#
#
#
# sort_dataset/hand/542.JPG 1 0 0 67 60
# 797.JPG
#
#
#
#
# sort_dataset/hand/797.JPG 1 0 0 44 41
# 783.JPG
#
#
#
#
# sort_dataset/hand/783.JPG 1 0 0 47 40
# 754.JPG
#
#
#
#
# sort_dataset/hand/754.JPG 1 0 0 30 35
# 740.JPG
#
#
#
#
# sort_dataset/hand/740.JPG 1 0 0 47 57
# 768.JPG
#
#
#
#
# sort_dataset/hand/768.JPG 1 0 0 29 27
# 769.JPG
#
#
#
#
# sort_dataset/hand/769.JPG 1 0 0 33 39
# 741.JPG
#
#
#
#
# sort_dataset/hand/741.JPG 1 0 0 95 71
# 755.JPG
#
#
#
#
# sort_dataset/hand/755.JPG 1 0 0 50 39
# 782.JPG
#
#
#
#
# sort_dataset/hand/782.JPG 1 0 0 99 99
# 796.JPG
#
#
#
#
# sort_dataset/hand/796.JPG 1 0 0 68 54
# 543.JPG
#
#
#
#
# sort_dataset/hand/543.JPG 1 0 0 24 26
# 557.JPG
#
#
#
#
# sort_dataset/hand/557.JPG 1 0 0 30 29
# 580.JPG
#
#
#
#
# sort_dataset/hand/580.JPG 1 0 0 51 47
# 594.JPG
#
#
#
#
# sort_dataset/hand/594.JPG 1 0 0 42 35
# 379.JPG
#
#
#
#
# sort_dataset/hand/379.JPG 1 0 0 82 81
# 351.JPG
#
#
#
#
# sort_dataset/hand/351.JPG 1 0 0 61 54
# 437.JPG
#
#
#
#
# sort_dataset/hand/437.JPG 1 0 0 61 50
# 423.JPG
#
#
#
#
# sort_dataset/hand/423.JPG 1 0 0 81 67
# 345.JPG
#
#
#
#
# sort_dataset/hand/345.JPG 1 0 0 97 115
# 392.JPG
#
#
#
#
# sort_dataset/hand/392.JPG 1 0 0 53 50
# 386.JPG
#
#
#
#
# sort_dataset/hand/386.JPG 1 0 0 36 35
# 609.JPG
#
#
#
#
# sort_dataset/hand/609.JPG 1 0 0 37 39
# 635.JPG
#
#
#
#
# sort_dataset/hand/635.JPG 1 0 0 44 82
# 621.JPG
#
#
#
#
# sort_dataset/hand/621.JPG 1 0 0 32 33
# 812.JPG
#
#
#
#
# sort_dataset/hand/812.JPG 1 0 0 45 45
# 806.JPG
#
#
#
#
# sort_dataset/hand/806.JPG 1 0 0 85 68
# ideal
#
# 63.JPG
#
#
#
#
# sort_dataset/ideal/63.JPG 1 0 0 50 50
# 189.JPG
#
#
#
#
# sort_dataset/ideal/189.JPG 1 0 0 50 50
# 77.JPG
#
#
#
#
# sort_dataset/ideal/77.JPG 1 0 0 50 50
# 162.JPG
#
#
#
#
# sort_dataset/ideal/162.JPG 1 0 0 50 50
# 176.JPG
#
#
#
#
# sort_dataset/ideal/176.JPG 1 0 0 50 50
# 88.JPG
#
#
#
#
# sort_dataset/ideal/88.JPG 1 0 0 50 50
# 228.JPG
#
#
#
#
# sort_dataset/ideal/228.JPG 1 0 0 50 50
# 214.JPG
#
#
#
#
# sort_dataset/ideal/214.JPG 1 0 0 50 50
# 200.JPG
#
#
#
#
# sort_dataset/ideal/200.JPG 1 0 0 50 50
# 201.JPG
#
#
#
#
# sort_dataset/ideal/201.JPG 1 0 0 50 50
# 215.JPG
#
#
#
#
# sort_dataset/ideal/215.JPG 1 0 0 50 50
# 229.JPG
#
#
#
#
# sort_dataset/ideal/229.JPG 1 0 0 50 50
# 177.JPG
#
#
#
#
# sort_dataset/ideal/177.JPG 1 0 0 50 50
# 89.JPG
#
#
#
#
# sort_dataset/ideal/89.JPG 1 0 0 50 50
# 163.JPG
#
#
#
#
# sort_dataset/ideal/163.JPG 1 0 0 50 50
# 188.JPG
#
#
#
#
# sort_dataset/ideal/188.JPG 1 0 0 50 50
# 76.JPG
#
#
#
#
# sort_dataset/ideal/76.JPG 1 0 0 50 50
# 62.JPG
#
#
#
#
# sort_dataset/ideal/62.JPG 1 0 0 50 50
# 74.JPG
#
#
#
#
# sort_dataset/ideal/74.JPG 1 0 0 50 50
# 60.JPG
#
#
#
#
# sort_dataset/ideal/60.JPG 1 0 0 50 50
# 48.JPG
#
#
#
#
# sort_dataset/ideal/48.JPG 1 0 0 50 50
# 149.JPG
#
#
#
#
# sort_dataset/ideal/149.JPG 1 0 0 50 50
# 175.JPG
#
#
#
#
# sort_dataset/ideal/175.JPG 1 0 0 50 50
# 161.JPG
#
#
#
#
# sort_dataset/ideal/161.JPG 1 0 0 50 50
# 203.JPG
#
#
#
#
# sort_dataset/ideal/203.JPG 1 0 0 50 50
# 217.JPG
#
#
#
#
# sort_dataset/ideal/217.JPG 1 0 0 50 50
# 216.JPG
#
#
#
#
# sort_dataset/ideal/216.JPG 1 0 0 50 50
# 202.JPG
#
#
#
#
# sort_dataset/ideal/202.JPG 1 0 0 50 50
# 160.JPG
#
#
#
#
# sort_dataset/ideal/160.JPG 1 0 0 50 50
# 174.JPG
#
#
#
#
# sort_dataset/ideal/174.JPG 1 0 0 50 50
# 148.JPG
#
#
#
#
# sort_dataset/ideal/148.JPG 1 0 0 50 50
# 49.JPG
#
#
#
#
# sort_dataset/ideal/49.JPG 1 0 0 50 50
# 61.JPG
#
#
#
#
# sort_dataset/ideal/61.JPG 1 0 0 50 50
# 75.JPG
#
#
#
#
# sort_dataset/ideal/75.JPG 1 0 0 50 50
# 59.JPG
#
#
#
#
# sort_dataset/ideal/59.JPG 1 0 0 50 50
# 71.JPG
#
#
#
#
# sort_dataset/ideal/71.JPG 1 0 0 50 50
# 65.JPG
#
#
#
#
# sort_dataset/ideal/65.JPG 1 0 0 50 50
# 170.JPG
#
#
#
#
# sort_dataset/ideal/170.JPG 1 0 0 50 50
# 164.JPG
#
#
#
#
# sort_dataset/ideal/164.JPG 1 0 0 50 50
# 158.JPG
#
#
#
#
# sort_dataset/ideal/158.JPG 1 0 0 50 50
# 206.JPG
#
#
#
#
# sort_dataset/ideal/206.JPG 1 0 0 50 50
# 212.JPG
#
#
#
#
# sort_dataset/ideal/212.JPG 1 0 0 50 50
# 213.JPG
#
#
#
#
# sort_dataset/ideal/213.JPG 1 0 0 50 50
# 207.JPG
#
#
#
#
# sort_dataset/ideal/207.JPG 1 0 0 50 50
# 159.JPG
#
#
#
#
# sort_dataset/ideal/159.JPG 1 0 0 50 50
# 165.JPG
#
#
#
#
# sort_dataset/ideal/165.JPG 1 0 0 50 50
# 171.JPG
#
#
#
#
# sort_dataset/ideal/171.JPG 1 0 0 50 50
# 64.JPG
#
#
#
#
# sort_dataset/ideal/64.JPG 1 0 0 50 50
# 70.JPG
#
#
#
#
# sort_dataset/ideal/70.JPG 1 0 0 50 50
# 58.JPG
#
#
#
#
# sort_dataset/ideal/58.JPG 1 0 0 50 50
# 8.JPG
#
#
#
#
# sort_dataset/ideal/8.JPG 1 0 0 50 50
# 198.JPG
#
#
#
#
# sort_dataset/ideal/198.JPG 1 0 0 50 50
# 66.JPG
#
#
#
#
# sort_dataset/ideal/66.JPG 1 0 0 50 50
# 72.JPG
#
#
#
#
# sort_dataset/ideal/72.JPG 1 0 0 50 50
# 167.JPG
#
#
#
#
# sort_dataset/ideal/167.JPG 1 0 0 50 50
# 99.JPG
#
#
#
#
# sort_dataset/ideal/99.JPG 1 0 0 50 50
# 173.JPG
#
#
#
#
# sort_dataset/ideal/173.JPG 1 0 0 50 50
# 211.JPG
#
#
#
#
# sort_dataset/ideal/211.JPG 1 0 0 50 50
# 205.JPG
#
#
#
#
# sort_dataset/ideal/205.JPG 1 0 0 50 50
# 239.JPG
#
#
#
#
# sort_dataset/ideal/239.JPG 1 0 0 50 50
# 238.JPG
#
#
#
#
# sort_dataset/ideal/238.JPG 1 0 0 50 50
# 204.JPG
#
#
#
#
# sort_dataset/ideal/204.JPG 1 0 0 50 50
# 210.JPG
#
#
#
#
# sort_dataset/ideal/210.JPG 1 0 0 50 50
# 172.JPG
#
#
#
#
# sort_dataset/ideal/172.JPG 1 0 0 50 50
# 166.JPG
#
#
#
#
# sort_dataset/ideal/166.JPG 1 0 0 50 50
# 98.JPG
#
#
#
#
# sort_dataset/ideal/98.JPG 1 0 0 50 50
# 73.JPG
#
#
#
#
# sort_dataset/ideal/73.JPG 1 0 0 50 50
# 199.JPG
#
#
#
#
# sort_dataset/ideal/199.JPG 1 0 0 50 50
# 67.JPG
#
#
#
#
# sort_dataset/ideal/67.JPG 1 0 0 50 50
# 9.JPG
#
#
#
#
# sort_dataset/ideal/9.JPG 1 0 0 50 50
# 14.JPG
#
#
#
#
# sort_dataset/ideal/14.JPG 1 0 0 50 50
# 28.JPG
#
#
#
#
# sort_dataset/ideal/28.JPG 1 0 0 50 50
# 129.JPG
#
#
#
#
# sort_dataset/ideal/129.JPG 1 0 0 50 50
# 101.JPG
#
#
#
#
# sort_dataset/ideal/101.JPG 1 0 0 50 50
# 115.JPG
#
#
#
#
# sort_dataset/ideal/115.JPG 1 0 0 50 50
# 303.JPG
#
#
#
#
# sort_dataset/ideal/303.JPG 1 0 0 50 50
# 317.JPG
#
#
#
#
# sort_dataset/ideal/317.JPG 1 0 0 50 50
# 288.JPG
#
#
#
#
# sort_dataset/ideal/288.JPG 1 0 0 50 50
# 277.JPG
#
#
#
#
# sort_dataset/ideal/277.JPG 1 0 0 50 50
# 263.JPG
#
#
#
#
# sort_dataset/ideal/263.JPG 1 0 0 50 50
# 262.JPG
#
#
#
#
# sort_dataset/ideal/262.JPG 1 0 0 50 50
# 276.JPG
#
#
#
#
# sort_dataset/ideal/276.JPG 1 0 0 50 50
# 289.JPG
#
#
#
#
# sort_dataset/ideal/289.JPG 1 0 0 50 50
# 316.JPG
#
#
#
#
# sort_dataset/ideal/316.JPG 1 0 0 50 50
# 302.JPG
#
#
#
#
# sort_dataset/ideal/302.JPG 1 0 0 50 50
# 114.JPG
#
#
#
#
# sort_dataset/ideal/114.JPG 1 0 0 50 50
# 100.JPG
#
#
#
#
# sort_dataset/ideal/100.JPG 1 0 0 50 50
# 128.JPG
#
#
#
#
# sort_dataset/ideal/128.JPG 1 0 0 50 50
# 29.JPG
#
#
#
#
# sort_dataset/ideal/29.JPG 1 0 0 50 50
# 15.JPG
#
#
#
#
# sort_dataset/ideal/15.JPG 1 0 0 50 50
# 17.JPG
#
#
#
#
# sort_dataset/ideal/17.JPG 1 0 0 50 50
# 116.JPG
#
#
#
#
# sort_dataset/ideal/116.JPG 1 0 0 50 50
# 102.JPG
#
#
#
#
# sort_dataset/ideal/102.JPG 1 0 0 50 50
# 314.JPG
#
#
#
#
# sort_dataset/ideal/314.JPG 1 0 0 50 50
# 300.JPG
#
#
#
#
# sort_dataset/ideal/300.JPG 1 0 0 50 50
# 248.JPG
#
#
#
#
# sort_dataset/ideal/248.JPG 1 0 0 50 50
# 260.JPG
#
#
#
#
# sort_dataset/ideal/260.JPG 1 0 0 50 50
# 274.JPG
#
#
#
#
# sort_dataset/ideal/274.JPG 1 0 0 50 50
# 275.JPG
#
#
#
#
# sort_dataset/ideal/275.JPG 1 0 0 50 50
# 261.JPG
#
#
#
#
# sort_dataset/ideal/261.JPG 1 0 0 50 50
# 249.JPG
#
#
#
#
# sort_dataset/ideal/249.JPG 1 0 0 50 50
# 301.JPG
#
#
#
#
# sort_dataset/ideal/301.JPG 1 0 0 50 50
# 315.JPG
#
#
#
#
# sort_dataset/ideal/315.JPG 1 0 0 50 50
# 103.JPG
#
#
#
#
# sort_dataset/ideal/103.JPG 1 0 0 50 50
# 117.JPG
#
#
#
#
# sort_dataset/ideal/117.JPG 1 0 0 50 50
# 16.JPG
#
#
#
#
# sort_dataset/ideal/16.JPG 1 0 0 50 50
# 12.JPG
#
#
#
#
# sort_dataset/ideal/12.JPG 1 0 0 50 50
# 113.JPG
#
#
#
#
# sort_dataset/ideal/113.JPG 1 0 0 50 50
# 107.JPG
#
#
#
#
# sort_dataset/ideal/107.JPG 1 0 0 50 50
# 311.JPG
#
#
#
#
# sort_dataset/ideal/311.JPG 1 0 0 50 50
# 305.JPG
#
#
#
#
# sort_dataset/ideal/305.JPG 1 0 0 50 50
# 265.JPG
#
#
#
#
# sort_dataset/ideal/265.JPG 1 0 0 50 50
# 271.JPG
#
#
#
#
# sort_dataset/ideal/271.JPG 1 0 0 50 50
# 259.JPG
#
#
#
#
# sort_dataset/ideal/259.JPG 1 0 0 50 50
# 258.JPG
#
#
#
#
# sort_dataset/ideal/258.JPG 1 0 0 50 50
# 270.JPG
#
#
#
#
# sort_dataset/ideal/270.JPG 1 0 0 50 50
# 264.JPG
#
#
#
#
# sort_dataset/ideal/264.JPG 1 0 0 50 50
# 304.JPG
#
#
#
#
# sort_dataset/ideal/304.JPG 1 0 0 50 50
# 310.JPG
#
#
#
#
# sort_dataset/ideal/310.JPG 1 0 0 50 50
# 106.JPG
#
#
#
#
# sort_dataset/ideal/106.JPG 1 0 0 50 50
# 112.JPG
#
#
#
#
# sort_dataset/ideal/112.JPG 1 0 0 50 50
# 13.JPG
#
#
#
#
# sort_dataset/ideal/13.JPG 1 0 0 50 50
# 39.JPG
#
#
#
#
# sort_dataset/ideal/39.JPG 1 0 0 50 50
# 11.JPG
#
#
#
#
# sort_dataset/ideal/11.JPG 1 0 0 50 50
# 104.JPG
#
#
#
#
# sort_dataset/ideal/104.JPG 1 0 0 50 50
# 110.JPG
#
#
#
#
# sort_dataset/ideal/110.JPG 1 0 0 50 50
# 138.JPG
#
#
#
#
# sort_dataset/ideal/138.JPG 1 0 0 50 50
# 306.JPG
#
#
#
#
# sort_dataset/ideal/306.JPG 1 0 0 50 50
# 312.JPG
#
#
#
#
# sort_dataset/ideal/312.JPG 1 0 0 50 50
# 299.JPG
#
#
#
#
# sort_dataset/ideal/299.JPG 1 0 0 50 50
# 272.JPG
#
#
#
#
# sort_dataset/ideal/272.JPG 1 0 0 50 50
# 266.JPG
#
#
#
#
# sort_dataset/ideal/266.JPG 1 0 0 50 50
# 267.JPG
#
#
#
#
# sort_dataset/ideal/267.JPG 1 0 0 50 50
# 273.JPG
#
#
#
#
# sort_dataset/ideal/273.JPG 1 0 0 50 50
# 298.JPG
#
#
#
#
# sort_dataset/ideal/298.JPG 1 0 0 50 50
# 313.JPG
#
#
#
#
# sort_dataset/ideal/313.JPG 1 0 0 50 50
# 307.JPG
#
#
#
#
# sort_dataset/ideal/307.JPG 1 0 0 50 50
# 139.JPG
#
#
#
#
# sort_dataset/ideal/139.JPG 1 0 0 50 50
# 111.JPG
#
#
#
#
# sort_dataset/ideal/111.JPG 1 0 0 50 50
# 105.JPG
#
#
#
#
# sort_dataset/ideal/105.JPG 1 0 0 50 50
# 10.JPG
#
#
#
#
# sort_dataset/ideal/10.JPG 1 0 0 50 50
# 38.JPG
#
#
#
#
# sort_dataset/ideal/38.JPG 1 0 0 50 50
# 21.JPG
#
#
#
#
# sort_dataset/ideal/21.JPG 1 0 0 50 50
# 35.JPG
#
#
#
#
# sort_dataset/ideal/35.JPG 1 0 0 50 50
# 108.JPG
#
#
#
#
# sort_dataset/ideal/108.JPG 1 0 0 50 50
# 120.JPG
#
#
#
#
# sort_dataset/ideal/120.JPG 1 0 0 50 50
# 134.JPG
#
#
#
#
# sort_dataset/ideal/134.JPG 1 0 0 50 50
# 295.JPG
#
#
#
#
# sort_dataset/ideal/295.JPG 1 0 0 50 50
# 281.JPG
#
#
#
#
# sort_dataset/ideal/281.JPG 1 0 0 50 50
# 256.JPG
#
#
#
#
# sort_dataset/ideal/256.JPG 1 0 0 50 50
# 242.JPG
#
#
#
#
# sort_dataset/ideal/242.JPG 1 0 0 50 50
# 243.JPG
#
#
#
#
# sort_dataset/ideal/243.JPG 1 0 0 50 50
# 257.JPG
#
#
#
#
# sort_dataset/ideal/257.JPG 1 0 0 50 50
# 280.JPG
#
#
#
#
# sort_dataset/ideal/280.JPG 1 0 0 50 50
# 294.JPG
#
#
#
#
# sort_dataset/ideal/294.JPG 1 0 0 50 50
# 135.JPG
#
#
#
#
# sort_dataset/ideal/135.JPG 1 0 0 50 50
# 121.JPG
#
#
#
#
# sort_dataset/ideal/121.JPG 1 0 0 50 50
# 109.JPG
#
#
#
#
# sort_dataset/ideal/109.JPG 1 0 0 50 50
# 34.JPG
#
#
#
#
# sort_dataset/ideal/34.JPG 1 0 0 50 50
# 20.JPG
#
#
#
#
# sort_dataset/ideal/20.JPG 1 0 0 50 50
# 36.JPG
#
#
#
#
# sort_dataset/ideal/36.JPG 1 0 0 50 50
# 22.JPG
#
#
#
#
# sort_dataset/ideal/22.JPG 1 0 0 50 50
# 137.JPG
#
#
#
#
# sort_dataset/ideal/137.JPG 1 0 0 50 50
# 123.JPG
#
#
#
#
# sort_dataset/ideal/123.JPG 1 0 0 50 50
# 309.JPG
#
#
#
#
# sort_dataset/ideal/309.JPG 1 0 0 50 50
# 282.JPG
#
#
#
#
# sort_dataset/ideal/282.JPG 1 0 0 50 50
# 296.JPG
#
#
#
#
# sort_dataset/ideal/296.JPG 1 0 0 50 50
# 269.JPG
#
#
#
#
# sort_dataset/ideal/269.JPG 1 0 0 50 50
# 241.JPG
#
#
#
#
# sort_dataset/ideal/241.JPG 1 0 0 50 50
# 255.JPG
#
#
#
#
# sort_dataset/ideal/255.JPG 1 0 0 50 50
# 254.JPG
#
#
#
#
# sort_dataset/ideal/254.JPG 1 0 0 50 50
# 240.JPG
#
#
#
#
# sort_dataset/ideal/240.JPG 1 0 0 50 50
# 268.JPG
#
#
#
#
# sort_dataset/ideal/268.JPG 1 0 0 50 50
# 297.JPG
#
#
#
#
# sort_dataset/ideal/297.JPG 1 0 0 50 50
# 283.JPG
#
#
#
#
# sort_dataset/ideal/283.JPG 1 0 0 50 50
# 308.JPG
#
#
#
#
# sort_dataset/ideal/308.JPG 1 0 0 50 50
# 122.JPG
#
#
#
#
# sort_dataset/ideal/122.JPG 1 0 0 50 50
# 136.JPG
#
#
#
#
# sort_dataset/ideal/136.JPG 1 0 0 50 50
# 23.JPG
#
#
#
#
# sort_dataset/ideal/23.JPG 1 0 0 50 50
# 37.JPG
#
#
#
#
# sort_dataset/ideal/37.JPG 1 0 0 50 50
# 33.JPG
#
#
#
#
# sort_dataset/ideal/33.JPG 1 0 0 50 50
# 27.JPG
#
#
#
#
# sort_dataset/ideal/27.JPG 1 0 0 50 50
# 132.JPG
#
#
#
#
# sort_dataset/ideal/132.JPG 1 0 0 50 50
# 126.JPG
#
#
#
#
# sort_dataset/ideal/126.JPG 1 0 0 50 50
# 318.JPG
#
#
#
#
# sort_dataset/ideal/318.JPG 1 0 0 50 50
# 287.JPG
#
#
#
#
# sort_dataset/ideal/287.JPG 1 0 0 50 50
# 293.JPG
#
#
#
#
# sort_dataset/ideal/293.JPG 1 0 0 50 50
# 244.JPG
#
#
#
#
# sort_dataset/ideal/244.JPG 1 0 0 50 50
# 250.JPG
#
#
#
#
# sort_dataset/ideal/250.JPG 1 0 0 50 50
# 278.JPG
#
#
#
#
# sort_dataset/ideal/278.JPG 1 0 0 50 50
# 279.JPG
#
#
#
#
# sort_dataset/ideal/279.JPG 1 0 0 50 50
# 251.JPG
#
#
#
#
# sort_dataset/ideal/251.JPG 1 0 0 50 50
# 245.JPG
#
#
#
#
# sort_dataset/ideal/245.JPG 1 0 0 50 50
# 292.JPG
#
#
#
#
# sort_dataset/ideal/292.JPG 1 0 0 50 50
# 286.JPG
#
#
#
#
# sort_dataset/ideal/286.JPG 1 0 0 50 50
# 319.JPG
#
#
#
#
# sort_dataset/ideal/319.JPG 1 0 0 50 50
# 127.JPG
#
#
#
#
# sort_dataset/ideal/127.JPG 1 0 0 50 50
# 133.JPG
#
#
#
#
# sort_dataset/ideal/133.JPG 1 0 0 50 50
# 26.JPG
#
#
#
#
# sort_dataset/ideal/26.JPG 1 0 0 50 50
# 32.JPG
#
#
#
#
# sort_dataset/ideal/32.JPG 1 0 0 50 50
# 18.JPG
#
#
#
#
# sort_dataset/ideal/18.JPG 1 0 0 50 50
# 24.JPG
#
#
#
#
# sort_dataset/ideal/24.JPG 1 0 0 50 50
# 30.JPG
#
#
#
#
# sort_dataset/ideal/30.JPG 1 0 0 50 50
# 125.JPG
#
#
#
#
# sort_dataset/ideal/125.JPG 1 0 0 50 50
# 131.JPG
#
#
#
#
# sort_dataset/ideal/131.JPG 1 0 0 50 50
# 119.JPG
#
#
#
#
# sort_dataset/ideal/119.JPG 1 0 0 50 50
# 290.JPG
#
#
#
#
# sort_dataset/ideal/290.JPG 1 0 0 50 50
# 284.JPG
#
#
#
#
# sort_dataset/ideal/284.JPG 1 0 0 50 50
# 253.JPG
#
#
#
#
# sort_dataset/ideal/253.JPG 1 0 0 50 50
# 247.JPG
#
#
#
#
# sort_dataset/ideal/247.JPG 1 0 0 50 50
# 246.JPG
#
#
#
#
# sort_dataset/ideal/246.JPG 1 0 0 50 50
# 252.JPG
#
#
#
#
# sort_dataset/ideal/252.JPG 1 0 0 50 50
# 285.JPG
#
#
#
#
# sort_dataset/ideal/285.JPG 1 0 0 50 50
# 291.JPG
#
#
#
#
# sort_dataset/ideal/291.JPG 1 0 0 50 50
# 118.JPG
#
#
#
#
# sort_dataset/ideal/118.JPG 1 0 0 50 50
# 130.JPG
#
#
#
#
# sort_dataset/ideal/130.JPG 1 0 0 50 50
# 124.JPG
#
#
#
#
# sort_dataset/ideal/124.JPG 1 0 0 50 50
# 31.JPG
#
#
#
#
# sort_dataset/ideal/31.JPG 1 0 0 50 50
# 25.JPG
#
#
#
#
# sort_dataset/ideal/25.JPG 1 0 0 50 50
# 19.JPG
#
#
#
#
# sort_dataset/ideal/19.JPG 1 0 0 50 50
# 42.JPG
#
#
#
#
# sort_dataset/ideal/42.JPG 1 0 0 50 50
# 4.JPG
#
#
#
#
# sort_dataset/ideal/4.JPG 1 0 0 50 50
# 56.JPG
#
#
#
#
# sort_dataset/ideal/56.JPG 1 0 0 50 50
# 180.JPG
#
#
#
#
# sort_dataset/ideal/180.JPG 1 0 0 50 50
# 194.JPG
#
#
#
#
# sort_dataset/ideal/194.JPG 1 0 0 50 50
# 81.JPG
#
#
#
#
# sort_dataset/ideal/81.JPG 1 0 0 50 50
# 95.JPG
#
#
#
#
# sort_dataset/ideal/95.JPG 1 0 0 50 50
# 143.JPG
#
#
#
#
# sort_dataset/ideal/143.JPG 1 0 0 50 50
# 157.JPG
#
#
#
#
# sort_dataset/ideal/157.JPG 1 0 0 50 50
# 209.JPG
#
#
#
#
# sort_dataset/ideal/209.JPG 1 0 0 50 50
# 235.JPG
#
#
#
#
# sort_dataset/ideal/235.JPG 1 0 0 50 50
# 221.JPG
#
#
#
#
# sort_dataset/ideal/221.JPG 1 0 0 50 50
# 220.JPG
#
#
#
#
# sort_dataset/ideal/220.JPG 1 0 0 50 50
# 234.JPG
#
#
#
#
# sort_dataset/ideal/234.JPG 1 0 0 50 50
# 208.JPG
#
#
#
#
# sort_dataset/ideal/208.JPG 1 0 0 50 50
# 156.JPG
#
#
#
#
# sort_dataset/ideal/156.JPG 1 0 0 50 50
# 142.JPG
#
#
#
#
# sort_dataset/ideal/142.JPG 1 0 0 50 50
# 94.JPG
#
#
#
#
# sort_dataset/ideal/94.JPG 1 0 0 50 50
# 80.JPG
#
#
#
#
# sort_dataset/ideal/80.JPG 1 0 0 50 50
# 195.JPG
#
#
#
#
# sort_dataset/ideal/195.JPG 1 0 0 50 50
# 181.JPG
#
#
#
#
# sort_dataset/ideal/181.JPG 1 0 0 50 50
# 5.JPG
#
#
#
#
# sort_dataset/ideal/5.JPG 1 0 0 50 50
# 57.JPG
#
#
#
#
# sort_dataset/ideal/57.JPG 1 0 0 50 50
# 43.JPG
#
#
#
#
# sort_dataset/ideal/43.JPG 1 0 0 50 50
# 55.JPG
#
#
#
#
# sort_dataset/ideal/55.JPG 1 0 0 50 50
# 7.JPG
#
#
#
#
# sort_dataset/ideal/7.JPG 1 0 0 50 50
# 41.JPG
#
#
#
#
# sort_dataset/ideal/41.JPG 1 0 0 50 50
# 69.JPG
#
#
#
#
# sort_dataset/ideal/69.JPG 1 0 0 50 50
# 197.JPG
#
#
#
#
# sort_dataset/ideal/197.JPG 1 0 0 50 50
# 183.JPG
#
#
#
#
# sort_dataset/ideal/183.JPG 1 0 0 50 50
# 96.JPG
#
#
#
#
# sort_dataset/ideal/96.JPG 1 0 0 50 50
# 168.JPG
#
#
#
#
# sort_dataset/ideal/168.JPG 1 0 0 50 50
# 82.JPG
#
#
#
#
# sort_dataset/ideal/82.JPG 1 0 0 50 50
# 154.JPG
#
#
#
#
# sort_dataset/ideal/154.JPG 1 0 0 50 50
# 140.JPG
#
#
#
#
# sort_dataset/ideal/140.JPG 1 0 0 50 50
# 222.JPG
#
#
#
#
# sort_dataset/ideal/222.JPG 1 0 0 50 50
# 236.JPG
# sort_dataset/ideal/236.JPG 1 0 0 50 50
# 237.JPG
#
#
#
#
# sort_dataset/ideal/237.JPG 1 0 0 50 50
# 223.JPG
#
#
#
#
# sort_dataset/ideal/223.JPG 1 0 0 50 50
# 141.JPG
#
#
#
#
# sort_dataset/ideal/141.JPG 1 0 0 50 50
# 155.JPG
#
#
#
#
# sort_dataset/ideal/155.JPG 1 0 0 50 50
# 83.JPG
#
#
#
#
# sort_dataset/ideal/83.JPG 1 0 0 50 50
# 97.JPG
#
#
#
#
# sort_dataset/ideal/97.JPG 1 0 0 50 50
# 169.JPG
#
#
#
#
# sort_dataset/ideal/169.JPG 1 0 0 50 50
# 182.JPG
#
#
#
#
# sort_dataset/ideal/182.JPG 1 0 0 50 50
# 68.JPG
#
#
#
#
# sort_dataset/ideal/68.JPG 1 0 0 50 50
# 196.JPG
#
#
#
#
# sort_dataset/ideal/196.JPG 1 0 0 50 50
# 40.JPG
#
#
#
#
# sort_dataset/ideal/40.JPG 1 0 0 50 50
# 54.JPG
#
#
#
#
# sort_dataset/ideal/54.JPG 1 0 0 50 50
# 6.JPG
#
#
#
#
# sort_dataset/ideal/6.JPG 1 0 0 50 50
# 192.JPG
#
#
#
#
# sort_dataset/ideal/192.JPG 1 0 0 50 50
# 78.JPG
#
#
#
#
# sort_dataset/ideal/78.JPG 1 0 0 50 50
# 186.JPG
#
#
#
#
# sort_dataset/ideal/186.JPG 1 0 0 50 50
# 2.JPG
#
#
#
#
# sort_dataset/ideal/2.JPG 1 0 0 50 50
# 50.JPG
#
#
#
#
# sort_dataset/ideal/50.JPG 1 0 0 50 50
# 44.JPG
#
#
#
#
# sort_dataset/ideal/44.JPG 1 0 0 50 50
# 151.JPG
#
#
#
#
# sort_dataset/ideal/151.JPG 1 0 0 50 50
# 145.JPG
#
#
#
#
# sort_dataset/ideal/145.JPG 1 0 0 50 50
# 93.JPG
#
#
#
#
# sort_dataset/ideal/93.JPG 1 0 0 50 50
# 87.JPG
#
#
#
#
# sort_dataset/ideal/87.JPG 1 0 0 50 50
# 179.JPG
#
#
#
#
# sort_dataset/ideal/179.JPG 1 0 0 50 50
# 227.JPG
#
#
#
#
# sort_dataset/ideal/227.JPG 1 0 0 50 50
# 233.JPG
#
#
#
#
# sort_dataset/ideal/233.JPG 1 0 0 50 50
# 232.JPG
#
#
#
#
# sort_dataset/ideal/232.JPG 1 0 0 50 50
# 226.JPG
#
#
#
#
# sort_dataset/ideal/226.JPG 1 0 0 50 50
# 86.JPG
#
#
#
#
# sort_dataset/ideal/86.JPG 1 0 0 50 50
# 178.JPG
#
#
#
#
# sort_dataset/ideal/178.JPG 1 0 0 50 50
# 92.JPG
#
#
#
#
# sort_dataset/ideal/92.JPG 1 0 0 50 50
# 144.JPG
#
#
#
#
# sort_dataset/ideal/144.JPG 1 0 0 50 50
# 150.JPG
#
#
#
#
# sort_dataset/ideal/150.JPG 1 0 0 50 50
# 45.JPG
#
#
#
#
# sort_dataset/ideal/45.JPG 1 0 0 50 50
# 3.JPG
#
#
#
#
# sort_dataset/ideal/3.JPG 1 0 0 50 50
# 51.JPG
#
#
#
#
# sort_dataset/ideal/51.JPG 1 0 0 50 50
# 79.JPG
#
#
#
#
# sort_dataset/ideal/79.JPG 1 0 0 50 50
# 187.JPG
#
#
#
#
# sort_dataset/ideal/187.JPG 1 0 0 50 50
# 193.JPG
#
#
#
#
# sort_dataset/ideal/193.JPG 1 0 0 50 50
# 185.JPG
#
#
#
#
# sort_dataset/ideal/185.JPG 1 0 0 50 50
# 191.JPG
#
#
#
#
# sort_dataset/ideal/191.JPG 1 0 0 50 50
# 47.JPG
#
#
#
#
# sort_dataset/ideal/47.JPG 1 0 0 50 50
# 53.JPG
#
#
#
#
# sort_dataset/ideal/53.JPG 1 0 0 50 50
# 1.JPG
#
#
#
#
# sort_dataset/ideal/1.JPG 1 0 0 50 50
# 146.JPG
#
#
#
#
# sort_dataset/ideal/146.JPG 1 0 0 50 50
# 152.JPG
#
#
#
#
# sort_dataset/ideal/152.JPG 1 0 0 50 50
# 84.JPG
#
#
#
#
# sort_dataset/ideal/84.JPG 1 0 0 50 50
# 90.JPG
#
#
#
#
# sort_dataset/ideal/90.JPG 1 0 0 50 50
# 230.JPG
#
#
#
#
# sort_dataset/ideal/230.JPG 1 0 0 50 50
# 224.JPG
#
#
#
#
# sort_dataset/ideal/224.JPG 1 0 0 50 50
# 218.JPG
#
#
#
#
# sort_dataset/ideal/218.JPG 1 0 0 50 50
# 219.JPG
#
#
#
#
# sort_dataset/ideal/219.JPG 1 0 0 50 50
# 225.JPG
#
#
#
#
# sort_dataset/ideal/225.JPG 1 0 0 50 50
# 231.JPG
#
#
#
#
# sort_dataset/ideal/231.JPG 1 0 0 50 50
# 91.JPG
#
#
#
#
# sort_dataset/ideal/91.JPG 1 0 0 50 50
# 85.JPG
#
#
#
#
# sort_dataset/ideal/85.JPG 1 0 0 50 50
# 153.JPG
#
#
#
#
# sort_dataset/ideal/153.JPG 1 0 0 50 50
# 147.JPG
#
#
#
#
# sort_dataset/ideal/147.JPG 1 0 0 50 50
# 52.JPG
#
#
#
#
# sort_dataset/ideal/52.JPG 1 0 0 50 50
# 46.JPG
#
#
#
#
# sort_dataset/ideal/46.JPG 1 0 0 50 50
# 190.JPG
#
#
#
#
# sort_dataset/ideal/190.JPG 1 0 0 50 50
# 184.JPG
#
#
#
#
# sort_dataset/ideal/184.JPG 1 0 0 50 50
# dotted_line
#
# 1179.JPG
#
#
#
#
# sort_dataset/dotted_line/1179.JPG 1 0 0 57 57
# 1151.JPG
#
#
#
#
# sort_dataset/dotted_line/1151.JPG 1 0 0 75 78
# 1145.JPG
#
#
#
#
# sort_dataset/dotted_line/1145.JPG 1 0 0 56 52
# 1192.JPG
#
#
#
#
# sort_dataset/dotted_line/1192.JPG 1 0 0 38 46
# 1186.JPG
#
#
#
#
# sort_dataset/dotted_line/1186.JPG 1 0 0 69 88
# 1187.JPG
#
#
#
#
# sort_dataset/dotted_line/1187.JPG 1 0 0 162 160
# 1193.JPG
#
#
#
#
# sort_dataset/dotted_line/1193.JPG 1 0 0 121 137
# 1144.JPG
#
#
#
#
# sort_dataset/dotted_line/1144.JPG 1 0 0 35 35
# 1150.JPG
#
#
#
#
# sort_dataset/dotted_line/1150.JPG 1 0 0 57 67
# 1178.JPG
#
#
#
#
# sort_dataset/dotted_line/1178.JPG 1 0 0 45 39
# 1146.JPG
#
#
#
#
# sort_dataset/dotted_line/1146.JPG 1 0 0 34 33
# 1152.JPG
#
#
#
#
# sort_dataset/dotted_line/1152.JPG 1 0 0 183 228
# 1185.JPG
#
#
#
#
# sort_dataset/dotted_line/1185.JPG 1 0 0 92 90
# 1191.JPG
#
#
#
#
# sort_dataset/dotted_line/1191.JPG 1 0 0 43 44
# 1218.JPG
#
#
#
#
# sort_dataset/dotted_line/1218.JPG 1 0 0 104 93
# 1224.JPG
#
#
#
#
# sort_dataset/dotted_line/1224.JPG 1 0 0 53 47
# 1225.JPG
#
#
#
#
# sort_dataset/dotted_line/1225.JPG 1 0 0 67 57
# 1219.JPG
#
#
#
#
# sort_dataset/dotted_line/1219.JPG 1 0 0 101 70
# 1190.JPG
#
#
#
#
# sort_dataset/dotted_line/1190.JPG 1 0 0 72 77
# 1184.JPG
#
#
#
#
# sort_dataset/dotted_line/1184.JPG 1 0 0 112 122
# 1153.JPG
#
#
#
#
# sort_dataset/dotted_line/1153.JPG 1 0 0 42 49
# 1147.JPG
#
#
#
#
# sort_dataset/dotted_line/1147.JPG 1 0 0 72 68
# 1143.JPG
#
#
#
#
# sort_dataset/dotted_line/1143.JPG 1 0 0 32 32
# 1157.JPG
#
#
#
#
# sort_dataset/dotted_line/1157.JPG 1 0 0 235 178
# 1180.JPG
#
#
#
#
# sort_dataset/dotted_line/1180.JPG 1 0 0 41 38
# 1194.JPG
#
#
#
#
# sort_dataset/dotted_line/1194.JPG 1 0 0 86 119
# 1221.JPG
#
#
#
#
# sort_dataset/dotted_line/1221.JPG 1 0 0 76 55
# 1209.JPG
#
#
#
#
# sort_dataset/dotted_line/1209.JPG 1 0 0 105 196
# 1208.JPG
#
#
#
#
# sort_dataset/dotted_line/1208.JPG 1 0 0 73 81
# 1220.JPG
#
#
#
#
# sort_dataset/dotted_line/1220.JPG 1 0 0 129 96
# 1195.JPG
#
#
#
#
# sort_dataset/dotted_line/1195.JPG 1 0 0 126 67
# 1181.JPG
#
#
#
#
# sort_dataset/dotted_line/1181.JPG 1 0 0 51 50
# 1156.JPG
#
#
#
#
# sort_dataset/dotted_line/1156.JPG 1 0 0 145 165
# 1154.JPG
#
#
#
#
# sort_dataset/dotted_line/1154.JPG 1 0 0 59 55
# 1168.JPG
#
#
#
#
# sort_dataset/dotted_line/1168.JPG 1 0 0 61 58
# 1197.JPG
#
#
#
#
# sort_dataset/dotted_line/1197.JPG 1 0 0 89 81
# 1183.JPG
#
#
#
#
# sort_dataset/dotted_line/1183.JPG 1 0 0 111 93
# 1222.JPG
#
#
#
#
# sort_dataset/dotted_line/1222.JPG 1 0 0 88 85
# 1223.JPG
#
#
#
#
# sort_dataset/dotted_line/1223.JPG 1 0 0 105 78
# 1182.JPG
#
#
#
#
# sort_dataset/dotted_line/1182.JPG 1 0 0 164 174
# 1196.JPG
#
#
#
#
# sort_dataset/dotted_line/1196.JPG 1 0 0 86 123
# 1169.JPG
#
#
#
#
# sort_dataset/dotted_line/1169.JPG 1 0 0 83 141
# 1155.JPG
#
#
#
#
# sort_dataset/dotted_line/1155.JPG 1 0 0 148 195
# 1158.JPG
#
#
#
#
# sort_dataset/dotted_line/1158.JPG 1 0 0 76 65
# 1170.JPG
#
#
#
#
# sort_dataset/dotted_line/1170.JPG 1 0 0 125 102
# 1164.JPG
#
#
#
#
# sort_dataset/dotted_line/1164.JPG 1 0 0 173 118
# 1206.JPG
#
#
#
#
# sort_dataset/dotted_line/1206.JPG 1 0 0 45 40
# 1212.JPG
#
#
#
#
# sort_dataset/dotted_line/1212.JPG 1 0 0 122 132
# 1213.JPG
#
#
#
#
# sort_dataset/dotted_line/1213.JPG 1 0 0 47 42
# 1207.JPG
#
#
#
#
# sort_dataset/dotted_line/1207.JPG 1 0 0 37 41
# 1165.JPG
#
#
#
#
# sort_dataset/dotted_line/1165.JPG 1 0 0 60 55
# 1171.JPG
#
#
#
#
# sort_dataset/dotted_line/1171.JPG 1 0 0 68 64
# 1159.JPG
#
#
#
#
# sort_dataset/dotted_line/1159.JPG 1 0 0 38 42
# 1167.JPG
#
#
#
#
# sort_dataset/dotted_line/1167.JPG 1 0 0 50 52
# 1173.JPG
#
#
#
#
# sort_dataset/dotted_line/1173.JPG 1 0 0 63 53
# 1198.JPG
#
#
#
#
# sort_dataset/dotted_line/1198.JPG 1 0 0 38 41
# 1211.JPG
#
#
#
#
# sort_dataset/dotted_line/1211.JPG 1 0 0 76 68
# 1205.JPG
#
#
#
#
# sort_dataset/dotted_line/1205.JPG 1 0 0 97 64
# 1204.JPG
#
#
#
#
# sort_dataset/dotted_line/1204.JPG 1 0 0 129 140
# 1210.JPG
#
#
#
#
# sort_dataset/dotted_line/1210.JPG 1 0 0 129 117
# 1199.JPG
#
#
#
#
# sort_dataset/dotted_line/1199.JPG 1 0 0 71 71
# 1172.JPG
#
#
#
#
# sort_dataset/dotted_line/1172.JPG 1 0 0 65 59
# 1166.JPG
#
#
#
#
# sort_dataset/dotted_line/1166.JPG 1 0 0 48 49
# 1162.JPG
#
#
#
#
# sort_dataset/dotted_line/1162.JPG 1 0 0 139 92
# 1176.JPG
#
#
#
#
# sort_dataset/dotted_line/1176.JPG 1 0 0 105 77
# 1189.JPG
#
#
#
#
# sort_dataset/dotted_line/1189.JPG 1 0 0 123 170
# 1214.JPG
#
#
#
#
# sort_dataset/dotted_line/1214.JPG 1 0 0 42 47
# 1200.JPG
#
#
#
#
# sort_dataset/dotted_line/1200.JPG 1 0 0 66 66
# 1201.JPG
#
#
#
#
# sort_dataset/dotted_line/1201.JPG 1 0 0 127 143
# 1215.JPG
#
#
#
#
# sort_dataset/dotted_line/1215.JPG 1 0 0 122 109
# 1188.JPG
#
#
#
#
# sort_dataset/dotted_line/1188.JPG 1 0 0 147 121
# 1177.JPG
#
#
#
#
# sort_dataset/dotted_line/1177.JPG 1 0 0 135 151
# 1163.JPG
#
#
#
#
# sort_dataset/dotted_line/1163.JPG 1 0 0 114 117
# 1175.JPG
#
#
#
#
# sort_dataset/dotted_line/1175.JPG 1 0 0 139 174
# 1161.JPG
#
#
#
#
# sort_dataset/dotted_line/1161.JPG 1 0 0 47 44
# 1149.JPG
#
#
#
#
# sort_dataset/dotted_line/1149.JPG 1 0 0 44 45
# 1203.JPG
#
#
#
#
# sort_dataset/dotted_line/1203.JPG 1 0 0 102 158
# 1217.JPG
#
#
#
#
# sort_dataset/dotted_line/1217.JPG 1 0 0 106 133
# 1216.JPG
#
#
#
#
# sort_dataset/dotted_line/1216.JPG 1 0 0 98 63
# 1202.JPG
#
#
#
#
# sort_dataset/dotted_line/1202.JPG 1 0 0 136 94
# 1148.JPG
#
#
#
#
# sort_dataset/dotted_line/1148.JPG 1 0 0 41 43
# 1160.JPG
#
#
#
#
# sort_dataset/dotted_line/1160.JPG 1 0 0 37 40
# 1174.JPG
#
#
#
#
# sort_dataset/dotted_line/1174.JPG 1 0 0 38 37
# ellipse
#
# 1019.JPG
#
#
#
#
# sort_dataset/ellipse/1019.JPG 1 0 0 87 61
# 1025.JPG
#
#
#
#
# ...
# 995.JPG
#
#
#
#
# sort_dataset/ellipse/995.JPG 1 0 0 204 100
# 942.JPG
#
#
#
#
# sort_dataset/ellipse/942.JPG 1 0 0 53 66
# 956.JPG
#
#
#
#
# sort_dataset/ellipse/956.JPG 1 0 0 106 100
# 1030.JPG
#
#
#
#
# sort_dataset/ellipse/1030.JPG 1 0 0 58 65
# 1024.JPG
#
#
#
#
# sort_dataset/ellipse/1024.JPG 1 0 0 99 135
# 1018.JPG
#
#
#
#
# sort_dataset/ellipse/1018.JPG 1 0 0 111 132
# 1032.JPG
#
#
#
#
# sort_dataset/ellipse/1032.JPG 1 0 0 78 97
# 1026.JPG
#
#
#
#
# sort_dataset/ellipse/1026.JPG 1 0 0 44 54
# 940.JPG
#
#
#
#
# sort_dataset/ellipse/940.JPG 1 0 0 37 50
# 954.JPG
#
#
#
#
# sort_dataset/ellipse/954.JPG 1 0 0 42 90
# 968.JPG
#
#
#
#
# sort_dataset/ellipse/968.JPG 1 0 0 66 69
# 983.JPG
#
#
#
#
# sort_dataset/ellipse/983.JPG 1 0 0 33 38
# 997.JPG
#
#
#
#
# sort_dataset/ellipse/997.JPG 1 0 0 65 33
# 996.JPG
#
#
#
#
# sort_dataset/ellipse/996.JPG 1 0 0 116 78
# 982.JPG
#
#
#
#
# sort_dataset/ellipse/982.JPG 1 0 0 78 84
# 969.JPG
#
#
#
#
# sort_dataset/ellipse/969.JPG 1 0 0 50 50
# 955.JPG
#
#
#
#
# sort_dataset/ellipse/955.JPG 1 0 0 79 110
# 941.JPG
#
#
#
#
# sort_dataset/ellipse/941.JPG 1 0 0 50 50
# 1027.JPG
#
#
#
#
# sort_dataset/ellipse/1027.JPG 1 0 0 55 84
# 1033.JPG
#
#
#
#
# sort_dataset/ellipse/1033.JPG 1 0 0 39 58
# 1037.JPG
#
#
#
#
# sort_dataset/ellipse/1037.JPG 1 0 0 41 31
# 1023.JPG
#
#
#
#
# sort_dataset/ellipse/1023.JPG 1 0 0 110 115
# 979.JPG
#
#
#
#
# sort_dataset/ellipse/979.JPG 1 0 0 40 42
# 945.JPG
#
#
#
#
# sort_dataset/ellipse/945.JPG 1 0 0 50 50
# 951.JPG
#
#
#
#
# sort_dataset/ellipse/951.JPG 1 0 0 79 105
# 986.JPG
#
#
#
#
# sort_dataset/ellipse/986.JPG 1 0 0 38 48
# 992.JPG
#
#
#
#
# sort_dataset/ellipse/992.JPG 1 0 0 34 43
# 993.JPG
#
#
#
#
# sort_dataset/ellipse/993.JPG 1 0 0 57 85
# 987.JPG
#
#
#
#
# sort_dataset/ellipse/987.JPG 1 0 0 62 73
# 950.JPG
#
#
#
#
# sort_dataset/ellipse/950.JPG 1 0 0 76 41
# 944.JPG
#
#
#
#
# sort_dataset/ellipse/944.JPG 1 0 0 37 50
# 978.JPG
#
#
#
#
# sort_dataset/ellipse/978.JPG 1 0 0 26 28
# 1022.JPG
#
#
#
#
# sort_dataset/ellipse/1022.JPG 1 0 0 50 50
# 1036.JPG
#
#
#
#
# sort_dataset/ellipse/1036.JPG 1 0 0 73 41
# 1020.JPG
#
#
#
#
# sort_dataset/ellipse/1020.JPG 1 0 0 70 83
# 1034.JPG
#
#
#
#
# sort_dataset/ellipse/1034.JPG 1 0 0 74 53
# 1008.JPG
#
#
#
#
# sort_dataset/ellipse/1008.JPG 1 0 0 50 50
# 952.JPG
#
#
#
#
# sort_dataset/ellipse/952.JPG 1 0 0 56 56
# 946.JPG
#
#
#
#
# sort_dataset/ellipse/946.JPG 1 0 0 116 135
# 991.JPG
#
#
#
#
# sort_dataset/ellipse/991.JPG 1 0 0 112 95
# 985.JPG
#
#
#
#
# sort_dataset/ellipse/985.JPG 1 0 0 57 64
# 984.JPG
#
#
#
#
# sort_dataset/ellipse/984.JPG 1 0 0 56 39
# 990.JPG
#
#
#
#
# sort_dataset/ellipse/990.JPG 1 0 0 30 36
# 947.JPG
#
#
#
#
# sort_dataset/ellipse/947.JPG 1 0 0 36 38
# 953.JPG
#
#
#
#
# sort_dataset/ellipse/953.JPG 1 0 0 109 85
# 1009.JPG
#
#
#
#
# sort_dataset/ellipse/1009.JPG 1 0 0 41 37
# 1035.JPG
#
#
#
#
# sort_dataset/ellipse/1035.JPG 1 0 0 37 51
# 1021.JPG
#
#
#
#
# sort_dataset/ellipse/1021.JPG 1 0 0 50 50
# 1046.JPG
#
#
#
#
# sort_dataset/ellipse/1046.JPG 1 0 0 54 39
# 1052.JPG
#
#
#
#
# sort_dataset/ellipse/1052.JPG 1 0 0 266 229
# 935.JPG
#
#
#
#
# sort_dataset/ellipse/935.JPG 1 0 0 50 50
# 1053.JPG
#
#
#
#
# sort_dataset/ellipse/1053.JPG 1 0 0 54 39
# 1047.JPG
#
#
#
#
# sort_dataset/ellipse/1047.JPG 1 0 0 220 155
# 1051.JPG
#
#
#
#
# sort_dataset/ellipse/1051.JPG 1 0 0 56 77
# 1045.JPG
#
#
#
#
# sort_dataset/ellipse/1045.JPG 1 0 0 103 159
# 937.JPG
#
#
#
#
# sort_dataset/ellipse/937.JPG 1 0 0 117 102
# 936.JPG
#
#
#
#
# sort_dataset/ellipse/936.JPG 1 0 0 30 34
# 1044.JPG
#
#
#
#
# sort_dataset/ellipse/1044.JPG 1 0 0 60 59
# 1050.JPG
#
#
#
#
# sort_dataset/ellipse/1050.JPG 1 0 0 265 173
# 1054.JPG
#
#
#
#
# sort_dataset/ellipse/1054.JPG 1 0 0 41 48
# 1040.JPG
#
#
#
#
# sort_dataset/ellipse/1040.JPG 1 0 0 227 184
# 1041.JPG
#
#
#
#
# sort_dataset/ellipse/1041.JPG 1 0 0 50 50
# 1055.JPG
#
#
#
#
# sort_dataset/ellipse/1055.JPG 1 0 0 85 34
# 1043.JPG
#
#
#
#
# sort_dataset/ellipse/1043.JPG 1 0 0 32 38
# 1057.JPG
#
#
#
#
# sort_dataset/ellipse/1057.JPG 1 0 0 72 44
# 1056.JPG
#
#
#
#
# sort_dataset/ellipse/1056.JPG 1 0 0 145 113
# 1042.JPG
#
#
#
#
# sort_dataset/ellipse/1042.JPG 1 0 0 126 112
# 1058.JPG
#
#
#
#
# sort_dataset/ellipse/1058.JPG 1 0 0 59 76
# 1059.JPG
#
#
#
#
# sort_dataset/ellipse/1059.JPG 1 0 0 28 38
# 1061.JPG
#
#
#
#
# sort_dataset/ellipse/1061.JPG 1 0 0 157 161
# 1049.JPG
#
#
#
#
# sort_dataset/ellipse/1049.JPG 1 0 0 93 124
# 1048.JPG
#
#
#
#
# sort_dataset/ellipse/1048.JPG 1 0 0 126 94
# 1060.JPG
#
#
#
#
# sort_dataset/ellipse/1060.JPG 1 0 0 110 115
# 1062.JPG
#
#
#
#
# sort_dataset/ellipse/1062.JPG 1 0 0 56 84
# 938.JPG
#
#
#
#
# sort_dataset/ellipse/938.JPG 1 0 0 32 36
# 939.JPG
#
#
#
#
# sort_dataset/ellipse/939.JPG 1 0 0 22 30
# 1063.JPG
#
#
#
#
# sort_dataset/ellipse/1063.JPG 1 0 0 288 182
# 1038.JPG
#
#
#
#
# sort_dataset/ellipse/1038.JPG 1 0 0 50 50
# 1004.JPG
#
#
#
#
# sort_dataset/ellipse/1004.JPG 1 0 0 107 70
# 1010.JPG
#
#
#
#
# sort_dataset/ellipse/1010.JPG 1 0 0 47 56
# 976.JPG
#
#
#
#
# sort_dataset/ellipse/976.JPG 1 0 0 39 47
# 962.JPG
#
#
#
#
# sort_dataset/ellipse/962.JPG 1 0 0 164 144
# 989.JPG
#
#
#
#
# sort_dataset/ellipse/989.JPG 1 0 0 41 45
# 988.JPG
#
#
#
#
# sort_dataset/ellipse/988.JPG 1 0 0 49 59
# 963.JPG
#
#
#
#
# sort_dataset/ellipse/963.JPG 1 0 0 38 43
# 977.JPG
#
#
#
#
# sort_dataset/ellipse/977.JPG 1 0 0 50 50
# 1011.JPG
#
#
#
#
# sort_dataset/ellipse/1011.JPG 1 0 0 43 48
# 1005.JPG
#
#
#
#
# sort_dataset/ellipse/1005.JPG 1 0 0 45 57
# 1039.JPG
#
#
#
#
# sort_dataset/ellipse/1039.JPG 1 0 0 53 75
# 1013.JPG
#
#
#
#
# sort_dataset/ellipse/1013.JPG 1 0 0 108 117
# 1007.JPG
#
#
#
#
# sort_dataset/ellipse/1007.JPG 1 0 0 42 46
# 961.JPG
#
#
#
#
# sort_dataset/ellipse/961.JPG 1 0 0 37 43
# 975.JPG
#
#
#
#
# sort_dataset/ellipse/975.JPG 1 0 0 50 50
# 949.JPG
#
#
#
#
# sort_dataset/ellipse/949.JPG 1 0 0 106 145
# 948.JPG
#
#
#
#
# sort_dataset/ellipse/948.JPG 1 0 0 171 153
# 974.JPG
#
#
#
#
# sort_dataset/ellipse/974.JPG 1 0 0 90 93
# 960.JPG
#
#
#
#
# sort_dataset/ellipse/960.JPG 1 0 0 42 48
# 1006.JPG
#
#
#
#
# sort_dataset/ellipse/1006.JPG 1 0 0 48 33
# 1012.JPG
#
#
#
#
# sort_dataset/ellipse/1012.JPG 1 0 0 92 57
# 1016.JPG
#
#
#
#
# sort_dataset/ellipse/1016.JPG 1 0 0 56 66
# 1002.JPG
#
#
#
#
# sort_dataset/ellipse/1002.JPG 1 0 0 71 40
# 958.JPG
#
#
#
#
# sort_dataset/ellipse/958.JPG 1 0 0 28 45
# 964.JPG
#
#
#
#
# sort_dataset/ellipse/964.JPG 1 0 0 70 30
# 970.JPG
#
#
#
#
# sort_dataset/ellipse/970.JPG 1 0 0 89 75
# 971.JPG
#
#
#
#
# sort_dataset/ellipse/971.JPG 1 0 0 30 44
# 965.JPG
#
#
#
#
# sort_dataset/ellipse/965.JPG 1 0 0 40 44
# 959.JPG
#
#
#
#
# sort_dataset/ellipse/959.JPG 1 0 0 30 36
# 1003.JPG
#
#
#
#
# sort_dataset/ellipse/1003.JPG 1 0 0 76 35
# 1017.JPG
#
#
#
#
# sort_dataset/ellipse/1017.JPG 1 0 0 49 83
# 1001.JPG
#
#
#
#
# sort_dataset/ellipse/1001.JPG 1 0 0 171 95
# 1015.JPG
#
#
#
#
# sort_dataset/ellipse/1015.JPG 1 0 0 72 91
# 1029.JPG
#
#
#
#
# sort_dataset/ellipse/1029.JPG 1 0 0 50 50
# 973.JPG
#
#
#
#
# sort_dataset/ellipse/973.JPG 1 0 0 33 36
# 967.JPG
#
#
#
#
# sort_dataset/ellipse/967.JPG 1 0 0 90 67
# 998.JPG
#
#
#
#
# sort_dataset/ellipse/998.JPG 1 0 0 65 97
# 999.JPG
#
#
#
#
# sort_dataset/ellipse/999.JPG 1 0 0 36 40
# 966.JPG
#
#
#
#
# sort_dataset/ellipse/966.JPG 1 0 0 54 45
# 972.JPG
#
#
#
#
# sort_dataset/ellipse/972.JPG 1 0 0 44 47
# 1028.JPG
#
#
#
#
# sort_dataset/ellipse/1028.JPG 1 0 0 47 68
# 1014.JPG
#
#
#
#
# sort_dataset/ellipse/1014.JPG 1 0 0 50 50
# 1000.JPG
#
#
#
#
# sort_dataset/ellipse/1000.JPG 1 0 0 50 50
# hand_cell
#
# 868.JPG
#
#
#
#
# sort_dataset/hand_cell/868.JPG 1 0 0 36 36
# 883.JPG
#
#
#
#
# sort_dataset/hand_cell/883.JPG 1 0 0 150 163
# 897.JPG
#
#
#
#
# sort_dataset/hand_cell/897.JPG 1 0 0 170 84
# 934.JPG
#
#
#
#
# sort_dataset/hand_cell/934.JPG 1 0 0 139 146
# 920.JPG
#
#
#
#
# sort_dataset/hand_cell/920.JPG 1 0 0 147 175
# 908.JPG
#
#
#
#
# sort_dataset/hand_cell/908.JPG 1 0 0 50 44
# 909.JPG
#
#
#
#
# sort_dataset/hand_cell/909.JPG 1 0 0 104 88
# 921.JPG
#
#
#
#
# sort_dataset/hand_cell/921.JPG 1 0 0 162 132
# 896.JPG
#
#
#
#
# sort_dataset/hand_cell/896.JPG 1 0 0 86 140
# 882.JPG
#
#
#
#
# sort_dataset/hand_cell/882.JPG 1 0 0 175 123
# 869.JPG
#
#
#
#
# sort_dataset/hand_cell/869.JPG 1 0 0 52 50
# 857.JPG
#
#
#
#
# sort_dataset/hand_cell/857.JPG 1 0 0 33 29
# 894.JPG
#
#
#
#
# sort_dataset/hand_cell/894.JPG 1 0 0 140 115
# 880.JPG
#
#
#
#
# sort_dataset/hand_cell/880.JPG 1 0 0 98 77
# 923.JPG
#
#
#
#
# sort_dataset/hand_cell/923.JPG 1 0 0 191 139
# 922.JPG
#
#
#
#
# sort_dataset/hand_cell/922.JPG 1 0 0 152 111
# 881.JPG
#
#
#
#
# sort_dataset/hand_cell/881.JPG 1 0 0 184 111
# 895.JPG
#
#
#
#
# sort_dataset/hand_cell/895.JPG 1 0 0 89 120
# 856.JPG
#
#
#
#
# sort_dataset/hand_cell/856.JPG 1 0 0 27 29
# 891.JPG
#
#
#
#
# sort_dataset/hand_cell/891.JPG 1 0 0 139 76
# 885.JPG
#
#
#
#
# sort_dataset/hand_cell/885.JPG 1 0 0 182 136
# 926.JPG
#
#
#
#
# sort_dataset/hand_cell/926.JPG 1 0 0 105 115
# 932.JPG
#
#
#
#
# sort_dataset/hand_cell/932.JPG 1 0 0 214 141
# 933.JPG
#
#
#
#
# sort_dataset/hand_cell/933.JPG 1 0 0 102 125
# 927.JPG
#
#
#
#
# sort_dataset/hand_cell/927.JPG 1 0 0 131 100
# 884.JPG
#
#
#
#
# sort_dataset/hand_cell/884.JPG 1 0 0 125 113
# 890.JPG
#
#
#
#
# sort_dataset/hand_cell/890.JPG 1 0 0 174 102
# 879.JPG
#
#
#
#
# sort_dataset/hand_cell/879.JPG 1 0 0 133 137
# 886.JPG
#
#
#
#
# sort_dataset/hand_cell/886.JPG 1 0 0 133 156
# 892.JPG
#
#
#
#
# sort_dataset/hand_cell/892.JPG 1 0 0 76 121
# 919.JPG
#
#
#
#
# sort_dataset/hand_cell/919.JPG 1 0 0 126 107
# 931.JPG
#
#
#
#
# sort_dataset/hand_cell/931.JPG 1 0 0 113 81
# 925.JPG
#
#
#
#
# sort_dataset/hand_cell/925.JPG 1 0 0 217 179
# 924.JPG
#
#
#
#
# sort_dataset/hand_cell/924.JPG 1 0 0 81 107
# 930.JPG
#
#
#
#
# sort_dataset/hand_cell/930.JPG 1 0 0 124 88
# 918.JPG
#
#
#
#
# sort_dataset/hand_cell/918.JPG 1 0 0 50 50
# 893.JPG
#
#
#
#
# sort_dataset/hand_cell/893.JPG 1 0 0 68 65
# 887.JPG
#
#
#
#
# sort_dataset/hand_cell/887.JPG 1 0 0 125 146
# 878.JPG
#
#
#
#
# sort_dataset/hand_cell/878.JPG 1 0 0 191 123
# 861.JPG
#
#
#
#
# sort_dataset/hand_cell/861.JPG 1 0 0 52 46
# 875.JPG
#
#
#
#
# sort_dataset/hand_cell/875.JPG 1 0 0 38 34
# 915.JPG
#
#
#
#
# sort_dataset/hand_cell/915.JPG 1 0 0 227 192
# 901.JPG
#
#
#
#
# sort_dataset/hand_cell/901.JPG 1 0 0 145 100
# 929.JPG
#
#
#
#
# sort_dataset/hand_cell/929.JPG 1 0 0 135 194
# 928.JPG
#
#
#
#
# sort_dataset/hand_cell/928.JPG 1 0 0 120 116
# 900.JPG
#
#
#
#
# sort_dataset/hand_cell/900.JPG 1 0 0 115 104
# 914.JPG
#
#
#
#
# sort_dataset/hand_cell/914.JPG 1 0 0 120 172
# 874.JPG
#
#
#
#
# sort_dataset/hand_cell/874.JPG 1 0 0 50 50
# 860.JPG
#
#
#
#
# sort_dataset/hand_cell/860.JPG 1 0 0 120 122
# 876.JPG
#
#
#
#
# sort_dataset/hand_cell/876.JPG 1 0 0 52 47
# 862.JPG
#
#
#
#
# sort_dataset/hand_cell/862.JPG 1 0 0 50 50
# 889.JPG
#
#
#
#
# sort_dataset/hand_cell/889.JPG 1 0 0 102 90
# 902.JPG
#
#
#
#
# sort_dataset/hand_cell/902.JPG 1 0 0 182 118
# 916.JPG
#
#
#
#
# sort_dataset/hand_cell/916.JPG 1 0 0 105 117
# 917.JPG
#
#
#
#
# sort_dataset/hand_cell/917.JPG 1 0 0 50 50
# 903.JPG
#
#
#
#
# sort_dataset/hand_cell/903.JPG 1 0 0 130 132
# 888.JPG
#
#
#
#
# sort_dataset/hand_cell/888.JPG 1 0 0 250 165
# 863.JPG
#
#
#
#
# sort_dataset/hand_cell/863.JPG 1 0 0 101 119
# 877.JPG
#
#
#
#
# sort_dataset/hand_cell/877.JPG 1 0 0 148 170
# 873.JPG
#
#
#
#
# sort_dataset/hand_cell/873.JPG 1 0 0 50 50
# 867.JPG
#
#
#
#
# sort_dataset/hand_cell/867.JPG 1 0 0 122 151
# 898.JPG
#
#
#
#
# sort_dataset/hand_cell/898.JPG 1 0 0 156 130
# 907.JPG
#
#
#
#
# sort_dataset/hand_cell/907.JPG 1 0 0 100 108
# 913.JPG
#
#
#
#
# sort_dataset/hand_cell/913.JPG 1 0 0 106 108
# 912.JPG
#
#
#
#
# sort_dataset/hand_cell/912.JPG 1 0 0 79 102
# 906.JPG
#
#
#
#
# sort_dataset/hand_cell/906.JPG 1 0 0 142 110
# 899.JPG
#
#
#
#
# sort_dataset/hand_cell/899.JPG 1 0 0 135 112
# 866.JPG
#
#
#
#
# sort_dataset/hand_cell/866.JPG 1 0 0 194 166
# 872.JPG
#
#
#
#
# sort_dataset/hand_cell/872.JPG 1 0 0 257 212
# 858.JPG
#
#
#
#
# sort_dataset/hand_cell/858.JPG 1 0 0 96 108
# 864.JPG
#
#
#
#
# sort_dataset/hand_cell/864.JPG 1 0 0 31 30
# 870.JPG
#
#
#
#
# sort_dataset/hand_cell/870.JPG 1 0 0 50 50
# 910.JPG
#
#
#
#
# sort_dataset/hand_cell/910.JPG 1 0 0 112 123
# 904.JPG
#
#
#
#
# sort_dataset/hand_cell/904.JPG 1 0 0 41 54
# 905.JPG
#
#
#
#
# sort_dataset/hand_cell/905.JPG 1 0 0 82 138
# 911.JPG
#
#
#
#
# sort_dataset/hand_cell/911.JPG 1 0 0 181 131
# 871.JPG
#
#
#
#
# sort_dataset/hand_cell/871.JPG 1 0 0 61 71
# 865.JPG
#
#
#
#
# sort_dataset/hand_cell/865.JPG 1 0 0 50 50
# 859.JPG
#
#
#
#
# sort_dataset/hand_cell/859.JPG 1 0 0 33 35
# double_circle
#
# 1142.JPG
#
#
#
#
# sort_dataset/double_circle/1142.JPG 1 0 0 132 103
# 1140.JPG
#
#
#
#
# sort_dataset/double_circle/1140.JPG 1 0 0 43 35
# 1141.JPG
#
#
#
#
# sort_dataset/double_circle/1141.JPG 1 0 0 84 93
# 1132.JPG
#
#
#
#
# sort_dataset/double_circle/1132.JPG 1 0 0 38 29
# 1126.JPG
#
#
#
#
# sort_dataset/double_circle/1126.JPG 1 0 0 114 72
# 1085.JPG
#
#
#
#
# sort_dataset/double_circle/1085.JPG 1 0 0 111 94
# 1091.JPG
#
#
#
#
# sort_dataset/double_circle/1091.JPG 1 0 0 154 203
# 1090.JPG
#
#
#
#
# sort_dataset/double_circle/1090.JPG 1 0 0 156 119
# 1084.JPG
#
#
#
#
# sort_dataset/double_circle/1084.JPG 1 0 0 124 166
# 1127.JPG
#
#
#
#
# sort_dataset/double_circle/1127.JPG 1 0 0 95 78
# 1133.JPG
#
#
#
#
# sort_dataset/double_circle/1133.JPG 1 0 0 118 89
# 1119.JPG
#
#
#
#
# sort_dataset/double_circle/1119.JPG 1 0 0 102 82
# 1125.JPG
#
#
#
#
# sort_dataset/double_circle/1125.JPG 1 0 0 139 123
# 1131.JPG
#
#
#
#
# sort_dataset/double_circle/1131.JPG 1 0 0 44 35
# 1079.JPG
#
#
#
#
# sort_dataset/double_circle/1079.JPG 1 0 0 53 46
# 1092.JPG
#
#
#
#
# sort_dataset/double_circle/1092.JPG 1 0 0 103 118
# 1086.JPG
#
#
#
#
# sort_dataset/double_circle/1086.JPG 1 0 0 170 138
# 1087.JPG
#
#
#
#
# sort_dataset/double_circle/1087.JPG 1 0 0 91 106
# 1093.JPG
#
#
#
#
# sort_dataset/double_circle/1093.JPG 1 0 0 104 113
# 1078.JPG
#
#
#
#
# sort_dataset/double_circle/1078.JPG 1 0 0 44 35
# 1130.JPG
#
#
#
#
# sort_dataset/double_circle/1130.JPG 1 0 0 183 73
# 1124.JPG
#
#
#
#
# sort_dataset/double_circle/1124.JPG 1 0 0 58 39
# 1118.JPG
#
#
#
#
# sort_dataset/double_circle/1118.JPG 1 0 0 85 66
# 1120.JPG
#
#
#
#
# sort_dataset/double_circle/1120.JPG 1 0 0 70 64
# 1134.JPG
#
#
#
#
# sort_dataset/double_circle/1134.JPG 1 0 0 113 121
# 1108.JPG
#
#
#
#
# sort_dataset/double_circle/1108.JPG 1 0 0 109 160
# 1068.JPG
#
#
#
#
# sort_dataset/double_circle/1068.JPG 1 0 0 142 100
# 1097.JPG
#
#
#
#
# sort_dataset/double_circle/1097.JPG 1 0 0 131 111
# 1083.JPG
#
#
#
#
# sort_dataset/double_circle/1083.JPG 1 0 0 122 150
# 1082.JPG
#
#
#
#
# sort_dataset/double_circle/1082.JPG 1 0 0 108 162
# 1096.JPG
#
#
#
#
# sort_dataset/double_circle/1096.JPG 1 0 0 118 113
# 1069.JPG
#
#
#
#
# sort_dataset/double_circle/1069.JPG 1 0 0 97 71
# 1109.JPG
#
#
#
#
# sort_dataset/double_circle/1109.JPG 1 0 0 131 136
# 1135.JPG
#
#
#
#
# sort_dataset/double_circle/1135.JPG 1 0 0 103 62
# 1121.JPG
#
#
#
#
# sort_dataset/double_circle/1121.JPG 1 0 0 119 78
# 1137.JPG
#
#
#
#
# sort_dataset/double_circle/1137.JPG 1 0 0 103 76
# 1123.JPG
#
#
#
#
# sort_dataset/double_circle/1123.JPG 1 0 0 53 44
# 1080.JPG
#
#
#
#
# sort_dataset/double_circle/1080.JPG 1 0 0 64 59
# 1094.JPG
#
#
#
#
# sort_dataset/double_circle/1094.JPG 1 0 0 90 133
# 1095.JPG
#
#
#
#
# sort_dataset/double_circle/1095.JPG 1 0 0 121 135
# 1081.JPG
#
#
#
#
# sort_dataset/double_circle/1081.JPG 1 0 0 117 115
# 1122.JPG
#
#
#
#
# sort_dataset/double_circle/1122.JPG 1 0 0 114 123
# 1136.JPG
#
#
#
#
# sort_dataset/double_circle/1136.JPG 1 0 0 95 65
# 1113.JPG
#
#
#
#
# sort_dataset/double_circle/1113.JPG 1 0 0 169 169
# 1107.JPG
#
#
#
#
# sort_dataset/double_circle/1107.JPG 1 0 0 154 175
# 1067.JPG
#
#
#
#
# sort_dataset/double_circle/1067.JPG 1 0 0 60 40
# 1073.JPG
#
#
#
#
# sort_dataset/double_circle/1073.JPG 1 0 0 87 56
# 1098.JPG
#
#
#
#
# sort_dataset/double_circle/1098.JPG 1 0 0 106 172
# 1099.JPG
#
#
#
#
# sort_dataset/double_circle/1099.JPG 1 0 0 143 184
# 1072.JPG
#
#
#
#
# sort_dataset/double_circle/1072.JPG 1 0 0 66 54
# 1066.JPG
#
#
#
#
# sort_dataset/double_circle/1066.JPG 1 0 0 52 52
# 1106.JPG
#
#
#
#
# sort_dataset/double_circle/1106.JPG 1 0 0 108 93
# 1112.JPG
#
#
#
#
# sort_dataset/double_circle/1112.JPG 1 0 0 74 55
# 1138.JPG
#
#
#
#
# sort_dataset/double_circle/1138.JPG 1 0 0 97 141
# 1104.JPG
#
#
#
#
# sort_dataset/double_circle/1104.JPG 1 0 0 107 107
# 1110.JPG
#
#
#
#
# sort_dataset/double_circle/1110.JPG 1 0 0 117 146
# 1070.JPG
#
#
#
#
# sort_dataset/double_circle/1070.JPG 1 0 0 99 87
# 1064.JPG
#
#
#
#
# sort_dataset/double_circle/1064.JPG 1 0 0 150 102
# 1065.JPG
#
#
#
#
# sort_dataset/double_circle/1065.JPG 1 0 0 42 35
# 1071.JPG
#
#
#
#
# sort_dataset/double_circle/1071.JPG 1 0 0 73 60
# 1111.JPG
#
#
#
#
# sort_dataset/double_circle/1111.JPG 1 0 0 181 229
# 1105.JPG
#
#
#
#
# sort_dataset/double_circle/1105.JPG 1 0 0 113 142
# 1139.JPG
#
#
#
#
# sort_dataset/double_circle/1139.JPG 1 0 0 49 58
# 1101.JPG
#
#
#
#
# sort_dataset/double_circle/1101.JPG 1 0 0 122 306
# 1115.JPG
#
#
#
#
# sort_dataset/double_circle/1115.JPG 1 0 0 69 56
# 1129.JPG
#
#
#
#
# sort_dataset/double_circle/1129.JPG 1 0 0 112 81
# 1075.JPG
#
#
#
#
# sort_dataset/double_circle/1075.JPG 1 0 0 51 43
# 1074.JPG
#
#
#
#
# sort_dataset/double_circle/1074.JPG 1 0 0 61 48
# 1128.JPG
#
#
#
#
# sort_dataset/double_circle/1128.JPG 1 0 0 76 138
# 1114.JPG
#
#
#
#
# sort_dataset/double_circle/1114.JPG 1 0 0 88 60
# 1100.JPG
#
#
#
#
# sort_dataset/double_circle/1100.JPG 1 0 0 144 158
# 1116.JPG
#
#
#
#
# sort_dataset/double_circle/1116.JPG 1 0 0 53 49
# 1102.JPG
#
#
#
#
# sort_dataset/double_circle/1102.JPG 1 0 0 160 244
# 1076.JPG
#
#
#
#
# sort_dataset/double_circle/1076.JPG 1 0 0 148 91
# 1089.JPG
# sort_dataset/double_circle/1089.JPG 1 0 0 70 145
# 1088.JPG
#
#
#
#
# sort_dataset/double_circle/1088.JPG 1 0 0 141 124
# 1077.JPG
#
#
#
#
# sort_dataset/double_circle/1077.JPG 1 0 0 149 138
# 1103.JPG
#
#
#
#
# sort_dataset/double_circle/1103.JPG 1 0 0 90 105
# 1117.JPG
#
#
#
#
# sort_dataset/double_circle/1117.JPG 1 0 0 173 219
