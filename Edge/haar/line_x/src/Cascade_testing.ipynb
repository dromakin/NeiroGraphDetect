# %% [markdown]
# # Haar to find start line
# ## 10x10 with filteres and params

# %%
import numpy as np
import cv2
import os
import shutil

def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)

        shutil.rmtree(directory, ignore_errors=True)
        os.makedirs(directory)
    except OSError:
        print('Error: Creating directory. ' + directory)

# create folder
path = './../results/result_line_start_1010/'
createFolder(path)

cascade10 = cv2.CascadeClassifier('./../models/haarline1010/cascade.xml')

wastefiles = ['.DS_Store', '.ipynb_checkpoints']
for imeg in os.listdir("./../data/test_line_start/"):
    if imeg not in wastefiles:
        print(imeg)
        
        img = cv2.imread('./../data/test_line_start/' + imeg)
        img_c = img.copy()

        # filters
        gray = cv2.cvtColor(img_c, cv2.COLOR_BGR2GRAY)
        gaus = cv2.GaussianBlur(img_c, (5, 5), 2)

        vertex10 = cascade10.detectMultiScale(gaus, scaleFactor=1.01)

        for (x,y,w,h) in vertex10:
            print('line_start_1010')
            cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
    
        cv2.imwrite(path + imeg, img)
# Out:
# 8.jpg
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# 9.JPG
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# ...

# %% [markdown]
# ## Without filteres and params

# %%
import numpy as np
import cv2
import os
import shutil

def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)

        shutil.rmtree(directory, ignore_errors=True)
        os.makedirs(directory)
    except OSError:
        print('Error: Creating directory. ' + directory)

# create folder
path = './../results/result_line_start_1010/'
createFolder(path)

cascade10 = cv2.CascadeClassifier('./../models/')

wastefiles = ['.DS_Store', '.ipynb_checkpoints']
for imeg in os.listdir("./../data/test_line_start/"):
    if imeg not in wastefiles:
        print(imeg)
        
        img = cv2.imread('./../data/test_line_start/' + imeg)
        img_c = img.copy()

        # filters
        gray = cv2.cvtColor(img_c, cv2.COLOR_BGR2GRAY)
        gaus = cv2.GaussianBlur(img_c, (5, 5), 2)

        vertex10 = cascade10.detectMultiScale(gaus, scaleFactor=1.01)

        for (x,y,w,h) in vertex10:
            print('line_start_1010')
            cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
    
        cv2.imwrite(path + imeg, img)
# Out:
# 8.jpg
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# 9.JPG
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# 14.JPG
# line_start_1010
# line_start_1010
# 28.JPG
# line_start_1010
# line_start_1010
# line_start_1010
# 29.JPG
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# 15.JPG
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# 17.JPG
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# ...

# %% [markdown]
# ## 15x15

# %%
import numpy as np
import cv2
import os
import shutil

def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)

        shutil.rmtree(directory, ignore_errors=True)
        os.makedirs(directory)
    except OSError:
        print('Error: Creating directory. ' + directory)

# create folder
path = './../results/result_line_start_1515/'
createFolder(path)

cascade15 = cv2.CascadeClassifier('./../models/haarline1515/cascade.xml')

wastefiles = ['.DS_Store', '.ipynb_checkpoints']
for imeg in os.listdir("./../data/test_line_start/"):
    if imeg not in wastefiles:
        print(imeg)
        
        img = cv2.imread('./../data/test_line_start/' + imeg)
        img_c = img.copy()

        # filters
        gray = cv2.cvtColor(img_c, cv2.COLOR_BGR2GRAY)
        gaus = cv2.GaussianBlur(img_c, (5, 5), 2)

        vertex15 = cascade15.detectMultiScale(gaus, scaleFactor=1.01) # scaleFactor=1.01

        for (x,y,w,h) in vertex15:
            print('line_start_1515')
            cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
    
        cv2.imwrite(path + imeg, img)
# Out:
# 8.jpg
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# 9.JPG
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# ...

# %% [markdown]
# # Haar: find x
#
# ## 15x15

# %%
import numpy as np
import cv2
import os
import shutil

def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)

        shutil.rmtree(directory, ignore_errors=True)
        os.makedirs(directory)
    except OSError:
        print('Error: Creating directory. ' + directory)

# create folder
path = './../results/result_line_x_1515/'
createFolder(path)

cascade15 = cv2.CascadeClassifier('./../models/haarx1515/cascade.xml')

wastefiles = ['.DS_Store', '.ipynb_checkpoints']
for imeg in os.listdir("./../data/test_x/"):
    if imeg not in wastefiles:
        print(imeg)
        
        img = cv2.imread('./../data/test_x/' + imeg)
        img_c = img.copy()

        # filters
        gray = cv2.cvtColor(img_c, cv2.COLOR_BGR2GRAY)
        gaus = cv2.GaussianBlur(img_c, (5, 5), 2)

        vertex15 = cascade15.detectMultiScale(gaus, scaleFactor=1.01) # scaleFactor=1.01

        for (x,y,w,h) in vertex15:
            print('line_x_1515')
            cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
    
        cv2.imwrite(path + imeg, img)
# Out:
# 8.JPG
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# 9.jpg
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# 10.jpg
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# ...

# %% [markdown]
# ## 10x10

# %%
import numpy as np
import cv2
import os
import shutil

def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)

        shutil.rmtree(directory, ignore_errors=True)
        os.makedirs(directory)
    except OSError:
        print('Error: Creating directory. ' + directory)

# create folder
path = './../results/result_line_x_1010/'
createFolder(path)

cascade10 = cv2.CascadeClassifier('./../models/haarx1010/cascade.xml')

wastefiles = ['.DS_Store', '.ipynb_checkpoints']
for imeg in os.listdir("./../data/test_x/"):
    if imeg not in wastefiles:
        print(imeg)
        
        img = cv2.imread('./../data/test_x/' + imeg)
        img_c = img.copy()

        # filters
        gray = cv2.cvtColor(img_c, cv2.COLOR_BGR2GRAY)
        gaus = cv2.GaussianBlur(img_c, (5, 5), 2)

        vertex10 = cascade10.detectMultiScale(gaus, scaleFactor=1.01) # scaleFactor=1.01

        for (x,y,w,h) in vertex10:
            print('line_x_1010')
            cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
    
        cv2.imwrite(path + imeg, img)
# Out:
# 8.JPG
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# 9.jpg
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# 10.jpg
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# 41_1.png
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# 4.JPG
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# 5.jpg
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# ...

# %% [markdown]
# # 12x12

# %%
import numpy as np
import cv2
import os
import shutil

def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)

        shutil.rmtree(directory, ignore_errors=True)
        os.makedirs(directory)
    except OSError:
        print('Error: Creating directory. ' + directory)

# create folder
path = './../results/result_line_x_1212_gray/'
createFolder(path)

cascade10 = cv2.CascadeClassifier('./../models/haarline1212/cascade.xml')

wastefiles = ['.DS_Store', '.ipynb_checkpoints']
for imeg in os.listdir("./../data/test_x/"):
    if imeg not in wastefiles:
        print(imeg)
        
        img = cv2.imread('./../data/test_x/' + imeg)
        img_c = img.copy()

        # filters
        gray = cv2.cvtColor(img_c, cv2.COLOR_BGR2GRAY)
        gaus = cv2.GaussianBlur(img_c, (5, 5), 2)

        vertex10 = cascade10.detectMultiScale(gray, scaleFactor=1.01) # scaleFactor=1.01

        for (x,y,w,h) in vertex10:
            print('line_x_1010')
            cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
    
        cv2.imwrite(path + imeg, img)
# Out:
# 8.JPG
# 9.jpg
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# 10.jpg
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# 41_1.png
# 4.JPG
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# 5.jpg
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# 7.JPG
# line_x_1010
# line_x_1010
# 41.png
# line_x_1010
# 6.JPG
# line_x_1010
# line_x_1010
# line_x_1010
# 2.JPG
# 45.JPG
# line_x_1010
# 3.JPG
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# 51.jpg
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# line_x_1010
# ...

# %%
# ?cascade10.detectMultiScale(gaus, scaleFactor=1.01)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import shutil
import cv2
import csv
import os
# %matplotlib inline

def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)

        shutil.rmtree(directory, ignore_errors=True)
        os.makedirs(directory)
    except OSError:
        print('Error: Creating directory. ' + directory)

# %% [markdown]
# # Simple testing Haar

# %%
wastefiles = ['.DS_Store', '.ipynb_checkpoints']

modelDir = './../models/'
listOfModelsFiles = os.listdir(modelDir)

listOfModelsFiles.sort()

# errors and debug logs
# sys.stdout = open('./result/' + 'output.log', 'w')

for i in listOfModelsFiles:
    if i not in wastefiles:
        # create folder
        path = './../' + str(i) + '/'
        createFolder(path)
        
        print(i)

        cascade30 = cv2.CascadeClassifier(modelDir + str(i) + '/cascade.xml')
        
        Dir = './../data/'
        listOfFiles = os.listdir(Dir)
        
        listOfFiles.sort()
        
        print(listOfFiles)
        
        datcoord = './../' + str(i) + '.txt'
        dat = open(datcoord, 'w')
        
        for j in listOfFiles:
            if j not in wastefiles:
                image = str(j)

                img = cv2.imread(Dir + image)
                gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
                gaus = cv2.GaussianBlur(gray, (5, 5), 2)

                vertex30 = cascade30.detectMultiScale(img)

                it = 0
                for (x,y,w,h) in vertex30:
                    it += 1
                    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)

                # INFO
                dat.write(str(j) + ' Haar recognition:' + str(it) + '\n')
                
                print(str(j) + '.jpg' + ' Haar recognition:', it)

                # cv2.imshow('img',img)
                cv2.imwrite(path + image, img)
        dat.close()
# Out:
# haarline1010
# ['.DS_Store', '1.JPG', '10.JPG', '11.JPG', '13.jpg', '14.JPG', '15.JPG', '16.JPG', '17.JPG', '18.png', '19.jpg', '2.JPG', '20.JPG', '21.JPG', '22.JPG', '23.jpg', '24.JPG', '25.jpg', '26.JPG', '27.JPG', '28.JPG', '29.JPG', '3.JPG', '30.JPG', '31.png', '32.JPG', '33.JPG', '34.png', '35.JPG', '36.jpg', '37.jpg', '38.png', '4.JPG', '41.png', '45.JPG', '46.JPG', '47.JPG', '5.JPG', '51.jpg', '52.png', '6.JPG', '7.jpg', '8.jpg', '9.JPG']
# 1.JPG.jpg Haar recognition: 0
# 10.JPG.jpg Haar recognition: 0
# 11.JPG.jpg Haar recognition: 0
# 13.jpg.jpg Haar recognition: 0
# 14.JPG.jpg Haar recognition: 0
# 15.JPG.jpg Haar recognition: 1
# 16.JPG.jpg Haar recognition: 0
# 17.JPG.jpg Haar recognition: 0
# 18.png.jpg Haar recognition: 1
# 19.jpg.jpg Haar recognition: 1
# 2.JPG.jpg Haar recognition: 0
# 20.JPG.jpg Haar recognition: 5
# 21.JPG.jpg Haar recognition: 0
# 22.JPG.jpg Haar recognition: 0
# 23.jpg.jpg Haar recognition: 2
# 24.JPG.jpg Haar recognition: 0
# ...

# %% [markdown]
# # Create csv file while Testing runnig
# ## Example: create csv file

# %%
with open('employee_file2.csv', mode='w') as csv_file:
    fieldnames = ['emp_name', 'dept', 'birth_month']
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

    writer.writeheader()
    writer.writerow({'emp_name': 'John Smith', 'dept': 'Accounting', 'birth_month': 'November'})
    writer.writerow({'emp_name': 'Erica Meyers', 'dept': 'IT', 'birth_month': 'March'})

# %% [markdown]
# ## Get colums of csv table

# %%
wastefiles = ['.DS_Store', '.ipynb_checkpoints']

modelDir = './../models/'
listOfModelsFiles = os.listdir(modelDir)
listOfModelsFiles.sort()

Dir = './../data/'
listOfFiles = os.listdir(Dir)
listOfFiles.sort()
print(listOfFiles)

# errors and debug logs
# sys.stdout = open('./result/' + 'output.log', 'w')

image = listOfFiles
image.remove('.DS_Store')
forFileDic = {'image': image}

for i in listOfModelsFiles:
    if i not in wastefiles:
        # create folder
        path = './../' + str(i) + '/'
        createFolder(path)

        cascade30 = cv2.CascadeClassifier(modelDir + str(i) + '/cascade.xml')
        
        Dir = './../data/'
        listOfFiles = os.listdir(Dir)
        
        listOfFiles.sort()
        
        # print(listOfFiles)
        
        haarRecognition = []

        for j in listOfFiles:
            if j not in wastefiles:
                image = str(j)

                img = cv2.imread(Dir + image)
                gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
                gaus = cv2.GaussianBlur(gray, (5, 5), 2)

                vertex30 = cascade30.detectMultiScale(img)

                it = 0
                for (x,y,w,h) in vertex30:
                    it += 1
                    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
                
                haarRecognition.append(str(it))
                
                cv2.imwrite(path + image, img)
        # dat.close()
        
        forFileDic[str(i)] = haarRecognition

print('Done!')
# Out:
# ['.DS_Store', '1.JPG', '10.JPG', '11.JPG', '13.jpg', '14.JPG', '15.JPG', '16.JPG', '17.JPG', '18.png', '19.jpg', '2.JPG', '20.JPG', '21.JPG', '22.JPG', '23.jpg', '24.JPG', '25.jpg', '26.JPG', '27.JPG', '28.JPG', '29.JPG', '3.JPG', '30.JPG', '31.png', '32.JPG', '33.JPG', '34.png', '35.JPG', '36.jpg', '37.jpg', '38.png', '4.JPG', '41.png', '41_1.png', '45.JPG', '46.JPG', '47.JPG', '5.JPG', '51.jpg', '52.png', '6.JPG', '7.jpg', '8.jpg', '9.JPG']
# Done!

# %% [markdown]
# ## Create cvs file

# %%
# forFileDic

with open('./../result_testing.csv', mode='w') as csv_file:
    fieldnames = forFileDic.keys()
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
    writer.writeheader()
    
    for i in range(0, len(forFileDic.get('image'))):
        row = {}
        for header in fieldnames:
            el = forFileDic.get(header)   # get list
            row[header] = el[i]
        
        print('Row: ', row)
        writer.writerow(row)
# Out:
# Row:  {'image': '1.JPG', 'haarline1010': '0', 'haarline1212': '0', 'haarline1515': '0', 'haarx1010': '0', 'haarx1515': '0'}
# Row:  {'image': '10.JPG', 'haarline1010': '0', 'haarline1212': '2', 'haarline1515': '2', 'haarx1010': '0', 'haarx1515': '2'}
# Row:  {'image': '11.JPG', 'haarline1010': '0', 'haarline1212': '19', 'haarline1515': '15', 'haarx1010': '1', 'haarx1515': '14'}
# Row:  {'image': '13.jpg', 'haarline1010': '0', 'haarline1212': '11', 'haarline1515': '0', 'haarx1010': '0', 'haarx1515': '0'}
# Row:  {'image': '14.JPG', 'haarline1010': '0', 'haarline1212': '0', 'haarline1515': '0', 'haarx1010': '0', 'haarx1515': '0'}
# Row:  {'image': '15.JPG', 'haarline1010': '1', 'haarline1212': '0', 'haarline1515': '1', 'haarx1010': '0', 'haarx1515': '1'}
# Row:  {'image': '16.JPG', 'haarline1010': '0', 'haarline1212': '0', 'haarline1515': '0', 'haarx1010': '0', 'haarx1515': '0'}
# ...

# %% [markdown]
# # Analysis csv file

# %% [markdown]
# **Считаем данные из файла в память в виде объекта Pandas.DataFrame**

# %%
data = pd.read_csv('./../result_testing.csv')

# %% [markdown]
# **Данные представлены в виде таблицы. Посмотрим на первые 5 строк:**

# %%
data.head(5)
# Out:
#     image  haarline1010  haarline1212  haarline1515  haarx1010  haarx1515
# 0   1.JPG             0             0             0          0          0
# 1  10.JPG             0             2             2          0          2
# 2  11.JPG             0            19            15          1         14
# 3  13.jpg             0            11             0          0          0
# 4  14.JPG             0             0             0          0          0

# %% [markdown]
# **Опишем данные**

# %%
data.describe()
# Out:
#        haarline1010  haarline1212  haarline1515  haarx1010  haarx1515
# count     44.000000     44.000000     44.000000  44.000000  44.000000
# mean       1.045455      7.159091      3.318182   0.454545   1.681818
# std        2.034065     34.955748      5.134347   1.993647   4.558522
# min        0.000000      0.000000      0.000000   0.000000   0.000000
# 25%        0.000000      0.000000      0.000000   0.000000   0.000000
# 50%        0.000000      0.000000      0.500000   0.000000   0.000000
# 75%        1.000000      2.000000      5.250000   0.000000   1.000000
# max       10.000000    232.000000     20.000000  13.000000  24.000000

# %% [markdown]
# **Сравним haarline1010, haarline1212, haarline1515, haarx1010, haarx1515**

# %%
pd.scatter_matrix(data[['haarline1010', 'haarline1212', 'haarline1515']], figsize=(20, 20), diagonal='kde')
plt.figure(dpi=900)
plt.show()
# Out:
# /Users/romakindmitriy/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: pandas.scatter_matrix is deprecated, use pandas.plotting.scatter_matrix instead
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# **Сравним haarline1515, haarx1010, haarx1515**

# %%
pd.scatter_matrix(data[['haarline1515', 'haarx1010', 'haarx1515']], figsize=(20, 20), diagonal='kde')
plt.figure(dpi=900)
plt.show()
# Out:
# /Users/romakindmitriy/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: pandas.scatter_matrix is deprecated, use pandas.plotting.scatter_matrix instead
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# **Сравним haarline1010, haarline1212, haarline1515, haarx1010, haarx1515**

# %%
plt.figure(dpi=900)
sns.pairplot(data)
plt.savefig("./../pairplot(data).jpg")

# %% [markdown]
# **Проанализируем каждый стоолбец отдельно**

# %%
dt = data
plt.figure(dpi=900)
dt.hist(color = 'k', figsize=(15,10))
plt.show()

# %%
sns.heatmap(dt.corr());

# %% [markdown]
# # The best cascade Haar

# %%
sns.countplot(data['haarx1515'])

# %%
head = ['haarline1010', 'haarline1212', 'haarline1515', 'haarline1515', 'haarx1010', 'haarx1515']

zero = []

for j in range(0, len(head)):
    sumZero = 0
    for i in data[head[j]]:
        if i == 0:
            sumZero += 1
    
    zero.append(sumZero)

print(zero)
# Out:
# [28, 31, 22, 22, 38, 32]
