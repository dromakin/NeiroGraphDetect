# %% [markdown]
# # Haar to find start line
# ## 10x10 with filters and params

# %%
import numpy as np
import cv2
import os
import shutil

def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)

        shutil.rmtree(directory, ignore_errors=True)
        os.makedirs(directory)
    except OSError:
        print('Error: Creating directory. ' + directory)

# create folder
path = './../results/result_line_start_1010_realise_1/'
createFolder(path)

cascade10 = cv2.CascadeClassifier('./../models/haarline1010_realise/cascade.xml')

wastefiles = ['.DS_Store', '.ipynb_checkpoints']
for imeg in os.listdir("./../data/test_line_start/"):
    if imeg not in wastefiles:
        print(imeg)
        
        img = cv2.imread('./../data/test_line_start/' + imeg)
        img_c = img.copy()

        # filters
        gray = cv2.cvtColor(img_c, cv2.COLOR_BGR2GRAY)
        gaus = cv2.GaussianBlur(img_c, (5, 5), 2)

        vertex10 = cascade10.detectMultiScale(gaus, scaleFactor=1.01)

        for (x,y,w,h) in vertex10:
            print('line_start_1010')
            cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
    
        cv2.imwrite(path + imeg, img)
# Out:
# 8.jpg
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# 9.JPG
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# 14.JPG
# line_start_1010
# 28.JPG
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# 29.JPG
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# 15.JPG
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# 17.JPG
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# 16.JPG
# line_start_1010
# line_start_1010
# line_start_1010
# 13.jpg
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# 11.JPG

# %% [markdown]
# ## Without filteres and params

# %%
import numpy as np
import cv2
import os
import shutil

def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)

        shutil.rmtree(directory, ignore_errors=True)
        os.makedirs(directory)
    except OSError:
        print('Error: Creating directory. ' + directory)

# create folder
path = './../results/result_line_start_1010_realise/'
createFolder(path)

cascade10 = cv2.CascadeClassifier('./../models/haarline1010_realise/cascade.xml')

wastefiles = ['.DS_Store', '.ipynb_checkpoints']
for imeg in os.listdir("./../data/test_line_start/"):
    if imeg not in wastefiles:
        print(imeg)
        
        img = cv2.imread('./../data/test_line_start/' + imeg)
        img_c = img.copy()

        # filters
#         gray = cv2.cvtColor(img_c, cv2.COLOR_BGR2GRAY)
#         gaus = cv2.GaussianBlur(img_c, (5, 5), 2)

        vertex10 = cascade10.detectMultiScale(img_c)

        for (x,y,w,h) in vertex10:
            print('line_start_1010')
            cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
    
        cv2.imwrite(path + imeg, img)
# Out:
# 8.jpg
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# 9.JPG
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# 14.JPG
# line_start_1010
# line_start_1010
# 28.JPG
# line_start_1010
# line_start_1010
# line_start_1010
# 29.JPG
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# 15.JPG
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# 17.JPG
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# 16.JPG
# 13.jpg
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# 11.JPG
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# 38.png
# 10.JPG
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# 21.JPG
# 35.JPG
# line_start_1010
# line_start_1010
# line_start_1010
# 34.png
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# 20.JPG
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# 36.jpg
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# 22.JPG
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# 23.jpg
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# 37.jpg
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# 33.JPG
# 27.JPG
# line_start_1010
# line_start_1010
# line_start_1010
# 26.JPG
# 32.JPG
# line_start_1010
# line_start_1010
# line_start_1010
# 24.JPG
# line_start_1010
# line_start_1010
# line_start_1010
# 30.JPG
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# 18.png
# line_start_1010
# 31.png
# line_start_1010
# line_start_1010
# 25.jpg
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# 19.jpg
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# 4.JPG
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# 5.JPG
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# 7.jpg
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# 6.JPG
# 2.JPG
# 3.JPG
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# line_start_1010
# 1.JPG

# %% [markdown]
# ## 15x15

# %%
import numpy as np
import cv2
import os
import shutil

def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)

        shutil.rmtree(directory, ignore_errors=True)
        os.makedirs(directory)
    except OSError:
        print('Error: Creating directory. ' + directory)

# create folder
path = './../results/result_line_start_1515/'
createFolder(path)

cascade15 = cv2.CascadeClassifier('./../models/haarline1515/cascade.xml')

wastefiles = ['.DS_Store', '.ipynb_checkpoints']
for imeg in os.listdir("./../data/test_line_start/"):
    if imeg not in wastefiles:
        print(imeg)
        
        img = cv2.imread('./../data/test_line_start/' + imeg)
        img_c = img.copy()

        # filters
        gray = cv2.cvtColor(img_c, cv2.COLOR_BGR2GRAY)
        gaus = cv2.GaussianBlur(img_c, (5, 5), 2)

        vertex15 = cascade15.detectMultiScale(gaus, scaleFactor=1.01) # scaleFactor=1.01

        for (x,y,w,h) in vertex15:
            print('line_start_1515')
            cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
    
        cv2.imwrite(path + imeg, img)
# Out:
# 8.jpg
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# 9.JPG
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# 14.JPG
# 28.JPG
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# 29.JPG
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# 15.JPG
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# 17.JPG
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# 16.JPG
# line_start_1515
# 13.jpg
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# line_start_1515
# 11.JPG

# %% [markdown]
# # Haar: find x
#
# ## 15x15

# %%
import numpy as np
import cv2
import os
import shutil

def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)

        shutil.rmtree(directory, ignore_errors=True)
        os.makedirs(directory)
    except OSError:
        print('Error: Creating directory. ' + directory)

# create folder
path = './../results/result_line_x_1515/'
createFolder(path)

cascade15 = cv2.CascadeClassifier('./../models/haarx1515/cascade.xml')

wastefiles = ['.DS_Store', '.ipynb_checkpoints']
for imeg in os.listdir("./../data/test_x/"):
    if imeg not in wastefiles:
        print(imeg)
        
        img = cv2.imread('./../data/test_x/' + imeg)
        img_c = img.copy()

        # filters
        gray = cv2.cvtColor(img_c, cv2.COLOR_BGR2GRAY)
        gaus = cv2.GaussianBlur(img_c, (5, 5), 2)

        vertex15 = cascade15.detectMultiScale(gaus, scaleFactor=1.01) # scaleFactor=1.01

        for (x,y,w,h) in vertex15:
            print('line_x_1515')
            cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
    
        cv2.imwrite(path + imeg, img)
# Out:
# 8.JPG
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# 9.jpg
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# 10.jpg
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# 41_1.png
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# 4.JPG
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# 5.jpg
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# 7.JPG
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# 41.png
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# 6.JPG
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# 2.JPG
# 45.JPG
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# 3.JPG
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# 51.jpg
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# 47.JPG
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# 1.JPG
# line_x_1515
# line_x_1515
# line_x_1515
# 52.png
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# 46.JPG
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515
# line_x_1515

# %% [markdown]
# ## 10x10

# %%
import numpy as np
import cv2
import os
import shutil

def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)

        shutil.rmtree(directory, ignore_errors=True)
        os.makedirs(directory)
    except OSError:
        print('Error: Creating directory. ' + directory)

# create folder
path = './../results/result_line_x_1010xxx/'
createFolder(path)

cascade10 = cv2.CascadeClassifier('./../models/haarx1010/cascade.xml')

wastefiles = ['.DS_Store', '.ipynb_checkpoints']
for imeg in os.listdir("./../data/test_x/"):
    if imeg not in wastefiles:
        print(imeg)
        
        img = cv2.imread('./../data/test_x/' + imeg)
        img_c = img.copy()

        # filters
        gray = cv2.cvtColor(img_c, cv2.COLOR_BGR2GRAY)
        gaus = cv2.GaussianBlur(img_c, (5, 5), 2)

        vertex10 = cascade10.detectMultiScale(gaus, scaleFactor=1.01) # scaleFactor=1.01

        for (x,y,w,h) in vertex10:
            print('line_x_1010')
            cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
    
        cv2.imwrite(path + imeg, img)
# Out:
# 8.JPG
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-2-9aa005de5819> in <module>()
#      32         gaus = cv2.GaussianBlur(img_c, (5, 5), 2)
#      33
# ---> 34         vertex10 = cascade10.detectMultiScale(gaus, scaleFactor=1.01) # scaleFactor=1.01
#      35
#      36         for (x,y,w,h) in vertex10:
#
# error: /Users/jenkins/miniconda/1/x64/conda-bld/conda_1486587097465/work/opencv-3.1.0/modules/objdetect/src/cascadedetect.cpp:1639: error: (-215) !empty() in function detectMultiScale

# %%
# ?cascade10.detectMultiScale(gaus, scaleFactor=1.01)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import shutil
import cv2
import csv
import os
# %matplotlib inline

def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)

        shutil.rmtree(directory, ignore_errors=True)
        os.makedirs(directory)
    except OSError:
        print('Error: Creating directory. ' + directory)

# %% [markdown]
# # Simple testing Haar

# %%
wastefiles = ['.DS_Store', '.ipynb_checkpoints']

modelDir = './../models/'
listOfModelsFiles = os.listdir(modelDir)

listOfModelsFiles.sort()

# errors and debug logs
# sys.stdout = open('./result/' + 'output.log', 'w')

for i in listOfModelsFiles:
    if i not in wastefiles:
        # create folder
        path = './../' + str(i) + '/'
        createFolder(path)
        
        print(i)

        cascade30 = cv2.CascadeClassifier(modelDir + str(i) + '/cascade.xml')
        
        Dir = './../data/'
        listOfFiles = os.listdir(Dir)
        
        listOfFiles.sort()
        
        print(listOfFiles)
        
        datcoord = './../' + str(i) + '.txt'
        dat = open(datcoord, 'w')
        
        for j in listOfFiles:
            if j not in wastefiles:
                image = str(j)

                img = cv2.imread(Dir + image)
                gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
                gaus = cv2.GaussianBlur(gray, (5, 5), 2)

                vertex30 = cascade30.detectMultiScale(img)

                it = 0
                for (x,y,w,h) in vertex30:
                    it += 1
                    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)

                # INFO
                dat.write(str(j) + ' Haar recognition:' + str(it) + '\n')
                
                print(str(j) + '.jpg' + ' Haar recognition:', it)

                # cv2.imshow('img',img)
                cv2.imwrite(path + image, img)
        dat.close()
# Out:
# haarline1010
# ['.DS_Store', '1.JPG', '10.JPG', '11.JPG', '13.jpg', '14.JPG', '15.JPG', '16.JPG', '17.JPG', '18.png', '19.jpg', '2.JPG', '20.JPG', '21.JPG', '22.JPG', '23.jpg', '24.JPG', '25.jpg', '26.JPG', '27.JPG', '28.JPG', '29.JPG', '3.JPG', '30.JPG', '31.png', '32.JPG', '33.JPG', '34.png', '35.JPG', '36.jpg', '37.jpg', '38.png', '4.JPG', '41.png', '45.JPG', '46.JPG', '47.JPG', '5.JPG', '51.jpg', '52.png', '6.JPG', '7.jpg', '8.jpg', '9.JPG']
# 1.JPG.jpg Haar recognition: 0
# 10.JPG.jpg Haar recognition: 0
# 11.JPG.jpg Haar recognition: 0
# 13.jpg.jpg Haar recognition: 0
# 14.JPG.jpg Haar recognition: 0
# 15.JPG.jpg Haar recognition: 1
# 16.JPG.jpg Haar recognition: 0
# 17.JPG.jpg Haar recognition: 0
# 18.png.jpg Haar recognition: 1
# 19.jpg.jpg Haar recognition: 1
# 2.JPG.jpg Haar recognition: 0
# 20.JPG.jpg Haar recognition: 5
# 21.JPG.jpg Haar recognition: 0
# 22.JPG.jpg Haar recognition: 0
# 23.jpg.jpg Haar recognition: 2
# 24.JPG.jpg Haar recognition: 0
# 25.jpg.jpg Haar recognition: 0
# 26.JPG.jpg Haar recognition: 0
# 27.JPG.jpg Haar recognition: 0
# 28.JPG.jpg Haar recognition: 0
# 29.JPG.jpg Haar recognition: 0
# 3.JPG.jpg Haar recognition: 4
# 30.JPG.jpg Haar recognition: 0
# 31.png.jpg Haar recognition: 0
# 32.JPG.jpg Haar recognition: 0
# 33.JPG.jpg Haar recognition: 0
# 34.png.jpg Haar recognition: 0
# 35.JPG.jpg Haar recognition: 0
# 36.jpg.jpg Haar recognition: 3
# 37.jpg.jpg Haar recognition: 10
# 38.png.jpg Haar recognition: 0
# 4.JPG.jpg Haar recognition: 6
# 41.png.jpg Haar recognition: 0
# 45.JPG.jpg Haar recognition: 0
# 46.JPG.jpg Haar recognition: 2
# 47.JPG.jpg Haar recognition: 4
# 5.JPG.jpg Haar recognition: 0
# 51.jpg.jpg Haar recognition: 3
# 52.png.jpg Haar recognition: 0
# 6.JPG.jpg Haar recognition: 0
# 7.jpg.jpg Haar recognition: 1
# 8.jpg.jpg Haar recognition: 1
# 9.JPG.jpg Haar recognition: 1
# haarline1010_realise
# ['.DS_Store', '1.JPG', '10.JPG', '11.JPG', '13.jpg', '14.JPG', '15.JPG', '16.JPG', '17.JPG', '18.png', '19.jpg', '2.JPG', '20.JPG', '21.JPG', '22.JPG', '23.jpg', '24.JPG', '25.jpg', '26.JPG', '27.JPG', '28.JPG', '29.JPG', '3.JPG', '30.JPG', '31.png', '32.JPG', '33.JPG', '34.png', '35.JPG', '36.jpg', '37.jpg', '38.png', '4.JPG', '41.png', '45.JPG', '46.JPG', '47.JPG', '5.JPG', '51.jpg', '52.png', '6.JPG', '7.jpg', '8.jpg', '9.JPG']
# 1.JPG.jpg Haar recognition: 0
# 10.JPG.jpg Haar recognition: 5
# 11.JPG.jpg Haar recognition: 29
# 13.jpg.jpg Haar recognition: 7
# 14.JPG.jpg Haar recognition: 1
# 15.JPG.jpg Haar recognition: 11
# 16.JPG.jpg Haar recognition: 0
# 17.JPG.jpg Haar recognition: 9
# 18.png.jpg Haar recognition: 1
# 19.jpg.jpg Haar recognition: 45
# 2.JPG.jpg Haar recognition: 0
# 20.JPG.jpg Haar recognition: 26
# 21.JPG.jpg Haar recognition: 0
# 22.JPG.jpg Haar recognition: 13
# 23.jpg.jpg Haar recognition: 7
# 24.JPG.jpg Haar recognition: 3
# 25.jpg.jpg Haar recognition: 11
# 26.JPG.jpg Haar recognition: 0
# 27.JPG.jpg Haar recognition: 3
# 28.JPG.jpg Haar recognition: 1
# 29.JPG.jpg Haar recognition: 6
# 3.JPG.jpg Haar recognition: 19
# 30.JPG.jpg Haar recognition: 5
# 31.png.jpg Haar recognition: 2
# 32.JPG.jpg Haar recognition: 1
# 33.JPG.jpg Haar recognition: 0
# 34.png.jpg Haar recognition: 5
# 35.JPG.jpg Haar recognition: 3
# 36.jpg.jpg Haar recognition: 12
# 37.jpg.jpg Haar recognition: 23
# 38.png.jpg Haar recognition: 0
# 4.JPG.jpg Haar recognition: 24
# 41.png.jpg Haar recognition: 2
# 45.JPG.jpg Haar recognition: 0
# 46.JPG.jpg Haar recognition: 21
# 47.JPG.jpg Haar recognition: 10
# 5.JPG.jpg Haar recognition: 10
# 51.jpg.jpg Haar recognition: 12
# 52.png.jpg Haar recognition: 0
# 6.JPG.jpg Haar recognition: 0
# 7.jpg.jpg Haar recognition: 31
# 8.jpg.jpg Haar recognition: 13
# 9.JPG.jpg Haar recognition: 14
# haarline1515
# ['.DS_Store', '1.JPG', '10.JPG', '11.JPG', '13.jpg', '14.JPG', '15.JPG', '16.JPG', '17.JPG', '18.png', '19.jpg', '2.JPG', '20.JPG', '21.JPG', '22.JPG', '23.jpg', '24.JPG', '25.jpg', '26.JPG', '27.JPG', '28.JPG', '29.JPG', '3.JPG', '30.JPG', '31.png', '32.JPG', '33.JPG', '34.png', '35.JPG', '36.jpg', '37.jpg', '38.png', '4.JPG', '41.png', '45.JPG', '46.JPG', '47.JPG', '5.JPG', '51.jpg', '52.png', '6.JPG', '7.jpg', '8.jpg', '9.JPG']
# 1.JPG.jpg Haar recognition: 0
# 10.JPG.jpg Haar recognition: 2
# 11.JPG.jpg Haar recognition: 15
# 13.jpg.jpg Haar recognition: 0
# 14.JPG.jpg Haar recognition: 0
# 15.JPG.jpg Haar recognition: 1
# 16.JPG.jpg Haar recognition: 0
# 17.JPG.jpg Haar recognition: 6
# 18.png.jpg Haar recognition: 0
# 19.jpg.jpg Haar recognition: 11
# 2.JPG.jpg Haar recognition: 0
# 20.JPG.jpg Haar recognition: 14
# 21.JPG.jpg Haar recognition: 0
# 22.JPG.jpg Haar recognition: 3
# 23.jpg.jpg Haar recognition: 6
# 24.JPG.jpg Haar recognition: 0
# 25.jpg.jpg Haar recognition: 4
# 26.JPG.jpg Haar recognition: 0
# 27.JPG.jpg Haar recognition: 0
# 28.JPG.jpg Haar recognition: 0
# 29.JPG.jpg Haar recognition: 0
# 3.JPG.jpg Haar recognition: 20
# 30.JPG.jpg Haar recognition: 1
# 31.png.jpg Haar recognition: 0
# 32.JPG.jpg Haar recognition: 1
# 33.JPG.jpg Haar recognition: 0
# 34.png.jpg Haar recognition: 2
# 35.JPG.jpg Haar recognition: 0
# 36.jpg.jpg Haar recognition: 5
# 37.jpg.jpg Haar recognition: 10
# 38.png.jpg Haar recognition: 0
# 4.JPG.jpg Haar recognition: 17
# 41.png.jpg Haar recognition: 0
# 45.JPG.jpg Haar recognition: 0
# 46.JPG.jpg Haar recognition: 2
# 47.JPG.jpg Haar recognition: 6
# 5.JPG.jpg Haar recognition: 0
# 51.jpg.jpg Haar recognition: 5
# 52.png.jpg Haar recognition: 0
# 6.JPG.jpg Haar recognition: 0
# 7.jpg.jpg Haar recognition: 6
# 8.jpg.jpg Haar recognition: 2
# 9.JPG.jpg Haar recognition: 7

# %% [markdown]
# # Create csv file while Testing runnig
# ## Example: create csv file

# %%
with open('employee_file2.csv', mode='w') as csv_file:
    fieldnames = ['emp_name', 'dept', 'birth_month']
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

    writer.writeheader()
    writer.writerow({'emp_name': 'John Smith', 'dept': 'Accounting', 'birth_month': 'November'})
    writer.writerow({'emp_name': 'Erica Meyers', 'dept': 'IT', 'birth_month': 'March'})

# %% [markdown]
# ## Get colums of csv table

# %%
wastefiles = ['.DS_Store', '.ipynb_checkpoints']

modelDir = './../models/'
listOfModelsFiles = os.listdir(modelDir)

listOfModelsFiles.sort()

# errors and debug logs
# sys.stdout = open('./result/' + 'output.log', 'w')

image = listOfFiles
image.remove('.DS_Store')
forFileDic = {'image': image}

for i in listOfModelsFiles:
    if i not in wastefiles:
        # create folder
        path = './../' + str(i) + '/'
        createFolder(path)

        cascade30 = cv2.CascadeClassifier(modelDir + str(i) + '/cascade.xml')
        
        Dir = './../data/'
        listOfFiles = os.listdir(Dir)
        
        listOfFiles.sort()
        
        # print(listOfFiles)
        
        haarRecognition = []

        for j in listOfFiles:
            if j not in wastefiles:
                image = str(j)

                img = cv2.imread(Dir + image)
                gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
                gaus = cv2.GaussianBlur(gray, (5, 5), 2)

                vertex30 = cascade30.detectMultiScale(img)

                it = 0
                for (x,y,w,h) in vertex30:
                    it += 1
                    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
                
                haarRecognition.append(str(it))
                
                cv2.imwrite(path + image, img)
        # dat.close()
        
        forFileDic[str(i)] = haarRecognition

print('Done!')
# Out:
# Done!

# %% [markdown]
# ## Create cvs file

# %%
# forFileDic

with open('./../result_testing.csv', mode='w') as csv_file:
    fieldnames = forFileDic.keys()
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
    writer.writeheader()
    
    for i in range(0, len(forFileDic.get('image'))):
        row = {}
        for header in fieldnames:
            el = forFileDic.get(header)   # get list
            row[header] = el[i]
        
        print('Row: ', row)
        writer.writerow(row)
# Out:
# Row:  {'image': '1.JPG', 'haarline1010': '0', 'haarline1010_realise': '0', 'haarline1515': '0'}
# Row:  {'image': '10.JPG', 'haarline1010': '0', 'haarline1010_realise': '5', 'haarline1515': '2'}
# Row:  {'image': '11.JPG', 'haarline1010': '0', 'haarline1010_realise': '29', 'haarline1515': '15'}
# Row:  {'image': '13.jpg', 'haarline1010': '0', 'haarline1010_realise': '7', 'haarline1515': '0'}
# Row:  {'image': '14.JPG', 'haarline1010': '0', 'haarline1010_realise': '1', 'haarline1515': '0'}
# Row:  {'image': '15.JPG', 'haarline1010': '1', 'haarline1010_realise': '11', 'haarline1515': '1'}
# Row:  {'image': '16.JPG', 'haarline1010': '0', 'haarline1010_realise': '0', 'haarline1515': '0'}
# Row:  {'image': '17.JPG', 'haarline1010': '0', 'haarline1010_realise': '9', 'haarline1515': '6'}
# Row:  {'image': '18.png', 'haarline1010': '1', 'haarline1010_realise': '1', 'haarline1515': '0'}
# Row:  {'image': '19.jpg', 'haarline1010': '1', 'haarline1010_realise': '45', 'haarline1515': '11'}
# Row:  {'image': '2.JPG', 'haarline1010': '0', 'haarline1010_realise': '0', 'haarline1515': '0'}
# Row:  {'image': '20.JPG', 'haarline1010': '5', 'haarline1010_realise': '26', 'haarline1515': '14'}
# Row:  {'image': '21.JPG', 'haarline1010': '0', 'haarline1010_realise': '0', 'haarline1515': '0'}
# Row:  {'image': '22.JPG', 'haarline1010': '0', 'haarline1010_realise': '13', 'haarline1515': '3'}
# Row:  {'image': '23.jpg', 'haarline1010': '2', 'haarline1010_realise': '7', 'haarline1515': '6'}
# Row:  {'image': '24.JPG', 'haarline1010': '0', 'haarline1010_realise': '3', 'haarline1515': '0'}
# Row:  {'image': '25.jpg', 'haarline1010': '0', 'haarline1010_realise': '11', 'haarline1515': '4'}
# Row:  {'image': '26.JPG', 'haarline1010': '0', 'haarline1010_realise': '0', 'haarline1515': '0'}
# Row:  {'image': '27.JPG', 'haarline1010': '0', 'haarline1010_realise': '3', 'haarline1515': '0'}
# Row:  {'image': '28.JPG', 'haarline1010': '0', 'haarline1010_realise': '1', 'haarline1515': '0'}
# Row:  {'image': '29.JPG', 'haarline1010': '0', 'haarline1010_realise': '6', 'haarline1515': '0'}
# Row:  {'image': '3.JPG', 'haarline1010': '4', 'haarline1010_realise': '19', 'haarline1515': '20'}
# Row:  {'image': '30.JPG', 'haarline1010': '0', 'haarline1010_realise': '5', 'haarline1515': '1'}
# Row:  {'image': '31.png', 'haarline1010': '0', 'haarline1010_realise': '2', 'haarline1515': '0'}
# Row:  {'image': '32.JPG', 'haarline1010': '0', 'haarline1010_realise': '1', 'haarline1515': '1'}
# Row:  {'image': '33.JPG', 'haarline1010': '0', 'haarline1010_realise': '0', 'haarline1515': '0'}
# Row:  {'image': '34.png', 'haarline1010': '0', 'haarline1010_realise': '5', 'haarline1515': '2'}
# Row:  {'image': '35.JPG', 'haarline1010': '0', 'haarline1010_realise': '3', 'haarline1515': '0'}
# Row:  {'image': '36.jpg', 'haarline1010': '3', 'haarline1010_realise': '12', 'haarline1515': '5'}
# Row:  {'image': '37.jpg', 'haarline1010': '10', 'haarline1010_realise': '23', 'haarline1515': '10'}
# Row:  {'image': '38.png', 'haarline1010': '0', 'haarline1010_realise': '0', 'haarline1515': '0'}
# Row:  {'image': '4.JPG', 'haarline1010': '6', 'haarline1010_realise': '24', 'haarline1515': '17'}
# Row:  {'image': '41.png', 'haarline1010': '0', 'haarline1010_realise': '2', 'haarline1515': '0'}
# Row:  {'image': '45.JPG', 'haarline1010': '0', 'haarline1010_realise': '0', 'haarline1515': '0'}
# Row:  {'image': '46.JPG', 'haarline1010': '2', 'haarline1010_realise': '21', 'haarline1515': '2'}
# Row:  {'image': '47.JPG', 'haarline1010': '4', 'haarline1010_realise': '10', 'haarline1515': '6'}
# Row:  {'image': '5.JPG', 'haarline1010': '0', 'haarline1010_realise': '10', 'haarline1515': '0'}
# Row:  {'image': '51.jpg', 'haarline1010': '3', 'haarline1010_realise': '12', 'haarline1515': '5'}
# Row:  {'image': '52.png', 'haarline1010': '0', 'haarline1010_realise': '0', 'haarline1515': '0'}
# Row:  {'image': '6.JPG', 'haarline1010': '0', 'haarline1010_realise': '0', 'haarline1515': '0'}
# Row:  {'image': '7.jpg', 'haarline1010': '1', 'haarline1010_realise': '31', 'haarline1515': '6'}
# Row:  {'image': '8.jpg', 'haarline1010': '1', 'haarline1010_realise': '13', 'haarline1515': '2'}
# Row:  {'image': '9.JPG', 'haarline1010': '1', 'haarline1010_realise': '14', 'haarline1515': '7'}

# %% [markdown]
# # Analysis csv file

# %% [markdown]
# **Считаем данные из файла в память в виде объекта Pandas.DataFrame**

# %%
data = pd.read_csv('./../result_testing.csv')

# %% [markdown]
# **Данные представлены в виде таблицы. Посмотрим на первые 5 строк:**

# %%
data.head(5)
# Out:
#     image  haarline1010  haarline1010_realise  haarline1515
# 0   1.JPG             0                     0             0
# 1  10.JPG             0                     5             2
# 2  11.JPG             0                    29            15
# 3  13.jpg             0                     7             0
# 4  14.JPG             0                     1             0

# %% [markdown]
# **Опишем данные**

# %%
data.describe()
# Out:
#        haarline1010  haarline1010_realise  haarline1515
# count     43.000000             43.000000     43.000000
# mean       1.046512              8.953488      3.395349
# std        2.058125             10.415084      5.169229
# min        0.000000              0.000000      0.000000
# 25%        0.000000              1.000000      0.000000
# 50%        0.000000              5.000000      1.000000
# 75%        1.000000             12.500000      5.500000
# max       10.000000             45.000000     20.000000

# %% [markdown]
# **Сравним haarline1010, haarline1010_realise, haarline1515**

# %%
pd.scatter_matrix(data[['haarline1010', 'haarline1010_realise', 'haarline1515']], figsize=(20, 20), diagonal='kde')
plt.figure(dpi=900)
plt.show()
# Out:
# /Users/romakindmitriy/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: pandas.scatter_matrix is deprecated, use pandas.plotting.scatter_matrix instead
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# **Сравним haarline1010, haarline1010_realise, haarline1515**

# %%
plt.figure(dpi=900)
sns.pairplot(data)
plt.savefig("./../pairplot(data).jpg")

# %% [markdown]
# **Проанализируем каждый стоолбец отдельно**

# %%
dt = data
plt.figure(dpi=900)
dt.hist(color = 'k', figsize=(15,10))
plt.show()

# %%
sns.heatmap(dt.corr());

# %% [markdown]
# # The best cascade Haar

# %%
sns.countplot(data['haarline1010_realise'])

# %%
head = ['haarline1010', 'haarline1010_realise', 'haarline1515']

zero = []

for j in range(0, len(head)):
    sumZero = 0
    for i in data[head[j]]:
        if i == 0:
            sumZero += 1
    
    zero.append(sumZero)

print(zero)
# Out:
# [28, 10, 21]
